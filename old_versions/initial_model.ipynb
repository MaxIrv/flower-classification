# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math

# %%
transform_normal = transforms.Compose([
    transforms.Resize((250, 250)),
    transforms.ToTensor()
])

transform_train = transforms.Compose([
    transforms.Resize((250, 250)),
    # Randomly change the brightness of the image
    transforms.ColorJitter(brightness=0.5),
    # Randomly flip the image horizontally
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),  # Randomly flip the image vertically
    transforms.RandomRotation(55),  # Randomly rotate the image by 45 degrees
    transforms.ToTensor(),
    # transforms.Normalize(mean = [0.0, 0.0, 0.0], std = [1.0, 1.0, 1.0]) # Takes each value for the channel, subtracts the mean and divides by the standard deviation (value - mean) / std
])

# Define the transformations
transformations1 = transforms.Compose(
    [transforms.ToTensor(), transforms.Resize((250, 250))])

# Load the dataset
training_dataset = torchvision.datasets.Flowers102(root='./data', split="train",
                                                   download=True, transform=transform_train)
testing_dataset = torchvision.datasets.Flowers102(root='./data', split="test",
                                                  download=True, transform=transformations1)
validation_dataset = torchvision.datasets.Flowers102(root='./data', split="val",
                                                     download=True, transform=transformations1)

# Create the dataloaders
train_loader = DataLoader(training_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(testing_dataset, batch_size=32, shuffle=False)
validation_loader = DataLoader(
    validation_dataset, batch_size=32, shuffle=False)

# %%
import torch.nn as nn
import torch.nn.functional as F


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.flatten = nn.Flatten()
        self.relu_func = nn.ReLU()

        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.25)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(p=0.25)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(p=0.25)
        )
        self.fc1 = nn.Linear(64 * 29 * 29, 1024)
        self.drop = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(1024, 102)

        # Convolutional layers
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.conv2 = nn.Conv2d(16, 32, 3)
        self.conv3 = nn.Conv2d(32, 64, 3)

        # Pooling layer
        self.pool = nn.MaxPool2d(2, 2)

        # Fully connected layers
        # Adjusted to match the output size
        self.fc1 = nn.Linear(64 * 29 * 29, 102)
        self.fc2 = nn.Linear(512, 256)  # Additional fully connected layer
        self.fc3 = nn.Linear(256, 102)  # Output layer for 102 classes

    def forward(self, x):
        x = self.pool(self.relu_func(self.conv1(x)))
        x = self.pool(self.relu_func(self.conv2(x)))
        x = self.pool(self.relu_func(self.conv3(x)))
        # x = x.view(-1, 64 * 29 * 29)  # Flatten the tensor
        x = self.flatten(x)
        x = self.fc1(x)
        return x

# %%
device = torch.device("mps")
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
def NetworkAccuracyOnValidation():
    with torch.no_grad():
        num_class_correct = [0 for i in range(102)]
        num_class_samples = [0 for i in range(102)]
        total_correct = 0
        total_samples = 0
        for images, labels in validation_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)

            _, predictions = torch.max(outputs, 1)
            total_samples += labels.size(0)
            total_correct += (predictions == labels).sum().item()

            for i in range(len(labels)):
                label = labels[i]
                pred = predictions[i]
                if label == pred:
                    num_class_correct[label] += 1
                num_class_samples[label] += 1

        acc = 100.0 * total_correct / total_samples
        print(f'Accuracy on validation set: {acc} %')
        return acc


def NetworkAccuracyOnTesting():
    with torch.no_grad():
        num_class_correct = [0 for i in range(102)]
        num_class_samples = [0 for i in range(102)]
        total_correct = 0
        total_samples = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)

            _, predictions = torch.max(outputs, 1)
            total_samples += labels.size(0)
            total_correct += (predictions == labels).sum().item()

            for i in range(len(labels)):
                label = labels[i]
                pred = predictions[i]
                if (label == pred):
                    num_class_correct[label] += 1
                num_class_samples[label] += 1

        acc = 100.0 * total_correct / total_samples
        print(f'Accuracy on testing set: {acc} %')

        for i in range(102):
            acc = 100.0 * num_class_correct[i] / num_class_samples[i]
            print(f'Accuracy of {i} : {acc} %')

        return acc

# %%
best_accuracy_epoch = 0
best_accuracy = 0

for epoch in range(500):  # Loop over the dataset multiple times
    running_loss = 0.0
    for i, (images, labels) in enumerate(train_loader, 0):
        images = images.to(device)
        labels = labels.to(device)
        
        label_pred = model(images)
        loss = criterion(label_pred, labels)
        
        predicted = torch.max(label_pred, 1)[1]
        batch_corr = (predicted == labels).sum()
        batch_acc = batch_corr.item() / len(images)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        print(f"Epoch Number {epoch}, Index = {i}/{len(train_loader)-1}, Loss = {loss.item()}")
    
    current_accuracy = NetworkAccuracyOnValidation()
    if (current_accuracy > best_accuracy):
        best_accuracy = current_accuracy
        best_accuracy_epoch = epoch
        
print(f"Best accuracy on validation split: {best_accuracy} at epoch {best_accuracy_epoch}")
model.eval()
NetworkAccuracyOnTesting()
# Out:
# Epoch Number 0, Index = 0/31, Loss = 4.616765975952148
# Epoch Number 0, Index = 1/31, Loss = 4.632220268249512
# Epoch Number 0, Index = 2/31, Loss = 4.643918991088867
# Epoch Number 0, Index = 3/31, Loss = 4.723790168762207
# Epoch Number 0, Index = 4/31, Loss = 4.669425010681152
# Epoch Number 0, Index = 5/31, Loss = 4.570987701416016
# Epoch Number 0, Index = 6/31, Loss = 4.7492876052856445
# Epoch Number 0, Index = 7/31, Loss = 4.685832500457764
# Epoch Number 0, Index = 8/31, Loss = 4.728327751159668
# Epoch Number 0, Index = 9/31, Loss = 4.603004455566406
# Epoch Number 0, Index = 10/31, Loss = 4.706252098083496
# Epoch Number 0, Index = 11/31, Loss = 4.719853401184082
# Epoch Number 0, Index = 12/31, Loss = 4.7135114669799805
# Epoch Number 0, Index = 13/31, Loss = 4.71229362487793
# Epoch Number 0, Index = 14/31, Loss = 4.781060218811035
# Epoch Number 0, Index = 15/31, Loss = 4.706625938415527
# Epoch Number 0, Index = 16/31, Loss = 4.650676250457764
# Epoch Number 0, Index = 17/31, Loss = 4.65415096282959
# Epoch Number 0, Index = 18/31, Loss = 4.617144584655762
# Epoch Number 0, Index = 19/31, Loss = 4.753629684448242
# Epoch Number 0, Index = 20/31, Loss = 4.653776168823242
# Epoch Number 0, Index = 21/31, Loss = 4.722462177276611
# Epoch Number 0, Index = 22/31, Loss = 4.694149971008301
# Epoch Number 0, Index = 23/31, Loss = 4.646059513092041
# Epoch Number 0, Index = 24/31, Loss = 4.629707336425781
# Epoch Number 0, Index = 25/31, Loss = 4.6637115478515625
# Epoch Number 0, Index = 26/31, Loss = 4.668942451477051
# Epoch Number 0, Index = 27/31, Loss = 4.653659343719482
# Epoch Number 0, Index = 28/31, Loss = 4.633951663970947
# Epoch Number 0, Index = 29/31, Loss = 4.620946407318115
# Epoch Number 0, Index = 30/31, Loss = 4.6352715492248535
# Epoch Number 0, Index = 31/31, Loss = 4.620887756347656
# Accuracy on validation set: 3.3333333333333335 %
# Epoch Number 1, Index = 0/31, Loss = 4.608972072601318
# Epoch Number 1, Index = 1/31, Loss = 4.606044769287109
# Epoch Number 1, Index = 2/31, Loss = 4.604223251342773
# Epoch Number 1, Index = 3/31, Loss = 4.591267108917236
# Epoch Number 1, Index = 4/31, Loss = 4.583653926849365
# Epoch Number 1, Index = 5/31, Loss = 4.599897384643555
# Epoch Number 1, Index = 6/31, Loss = 4.602382659912109
# Epoch Number 1, Index = 7/31, Loss = 4.579052925109863
# Epoch Number 1, Index = 8/31, Loss = 4.571236610412598
# Epoch Number 1, Index = 9/31, Loss = 4.5864667892456055
# Epoch Number 1, Index = 10/31, Loss = 4.570098876953125
# Epoch Number 1, Index = 11/31, Loss = 4.580025672912598
# Epoch Number 1, Index = 12/31, Loss = 4.597393989562988
# Epoch Number 1, Index = 13/31, Loss = 4.589181423187256
# Epoch Number 1, Index = 14/31, Loss = 4.531461238861084
# Epoch Number 1, Index = 15/31, Loss = 4.552179336547852
# Epoch Number 1, Index = 16/31, Loss = 4.554490566253662
# Epoch Number 1, Index = 17/31, Loss = 4.551573753356934
# Epoch Number 1, Index = 18/31, Loss = 4.589110374450684
# Epoch Number 1, Index = 19/31, Loss = 4.610478401184082
# Epoch Number 1, Index = 20/31, Loss = 4.616941452026367
# Epoch Number 1, Index = 21/31, Loss = 4.6240234375
# Epoch Number 1, Index = 22/31, Loss = 4.560830593109131
# Epoch Number 1, Index = 23/31, Loss = 4.604341506958008
# Epoch Number 1, Index = 24/31, Loss = 4.535980224609375
# Epoch Number 1, Index = 25/31, Loss = 4.528580665588379
# Epoch Number 1, Index = 26/31, Loss = 4.601957321166992
# Epoch Number 1, Index = 27/31, Loss = 4.555658340454102
# Epoch Number 1, Index = 28/31, Loss = 4.511938095092773
# Epoch Number 1, Index = 29/31, Loss = 4.595995903015137
# Epoch Number 1, Index = 30/31, Loss = 4.492973327636719
# Epoch Number 1, Index = 31/31, Loss = 4.562676429748535
# Accuracy on validation set: 3.3333333333333335 %
# Epoch Number 2, Index = 0/31, Loss = 4.501155853271484
# Epoch Number 2, Index = 1/31, Loss = 4.519089221954346
# Epoch Number 2, Index = 2/31, Loss = 4.4494428634643555
# Epoch Number 2, Index = 3/31, Loss = 4.53409481048584
# Epoch Number 2, Index = 4/31, Loss = 4.534350395202637
# Epoch Number 2, Index = 5/31, Loss = 4.481620788574219
# Epoch Number 2, Index = 6/31, Loss = 4.43562126159668
# Epoch Number 2, Index = 7/31, Loss = 4.442449569702148
# Epoch Number 2, Index = 8/31, Loss = 4.391974925994873
# Epoch Number 2, Index = 9/31, Loss = 4.467216491699219
# Epoch Number 2, Index = 10/31, Loss = 4.511327266693115
# Epoch Number 2, Index = 11/31, Loss = 4.44832706451416
# Epoch Number 2, Index = 12/31, Loss = 4.35597562789917
# Epoch Number 2, Index = 13/31, Loss = 4.469821929931641
# Epoch Number 2, Index = 14/31, Loss = 4.344271659851074
# Epoch Number 2, Index = 15/31, Loss = 4.282428741455078
# Epoch Number 2, Index = 16/31, Loss = 4.313226699829102
# Epoch Number 2, Index = 17/31, Loss = 4.390424728393555
# Epoch Number 2, Index = 18/31, Loss = 4.228343963623047
# Epoch Number 2, Index = 19/31, Loss = 4.286684036254883
# Epoch Number 2, Index = 20/31, Loss = 4.3589935302734375
# Epoch Number 2, Index = 21/31, Loss = 4.304826259613037
# Epoch Number 2, Index = 22/31, Loss = 4.303751468658447
# Epoch Number 2, Index = 23/31, Loss = 4.300617218017578
# Epoch Number 2, Index = 24/31, Loss = 4.311588287353516
# Epoch Number 2, Index = 25/31, Loss = 4.324688911437988
# Epoch Number 2, Index = 26/31, Loss = 4.248932838439941
# Epoch Number 2, Index = 27/31, Loss = 4.306005954742432
# Epoch Number 2, Index = 28/31, Loss = 4.365970611572266
# Epoch Number 2, Index = 29/31, Loss = 4.410619735717773
# Epoch Number 2, Index = 30/31, Loss = 4.26933479309082
# Epoch Number 2, Index = 31/31, Loss = 4.35857629776001
# Accuracy on validation set: 6.568627450980392 %
# Epoch Number 3, Index = 0/31, Loss = 4.233837127685547
# Epoch Number 3, Index = 1/31, Loss = 4.105230331420898
# Epoch Number 3, Index = 2/31, Loss = 4.03748893737793
# Epoch Number 3, Index = 3/31, Loss = 4.105436325073242
# Epoch Number 3, Index = 4/31, Loss = 4.24447774887085
# Epoch Number 3, Index = 5/31, Loss = 4.074107646942139
# Epoch Number 3, Index = 6/31, Loss = 4.136787414550781
# Epoch Number 3, Index = 7/31, Loss = 4.0794677734375
# Epoch Number 3, Index = 8/31, Loss = 4.140691757202148
# Epoch Number 3, Index = 9/31, Loss = 3.9365193843841553
# Epoch Number 3, Index = 10/31, Loss = 3.949082612991333
# Epoch Number 3, Index = 11/31, Loss = 3.905815839767456
# Epoch Number 3, Index = 12/31, Loss = 3.964766025543213
# Epoch Number 3, Index = 13/31, Loss = 4.171714782714844
# Epoch Number 3, Index = 14/31, Loss = 4.095437526702881
# Epoch Number 3, Index = 15/31, Loss = 4.062013626098633
# Epoch Number 3, Index = 16/31, Loss = 4.1766839027404785
# Epoch Number 3, Index = 17/31, Loss = 4.146728515625
# Epoch Number 3, Index = 18/31, Loss = 4.2703118324279785
# Epoch Number 3, Index = 19/31, Loss = 4.018543243408203
# Epoch Number 3, Index = 20/31, Loss = 3.983990430831909
# Epoch Number 3, Index = 21/31, Loss = 4.101933479309082
# Epoch Number 3, Index = 22/31, Loss = 3.836185932159424
# Epoch Number 3, Index = 23/31, Loss = 3.9827165603637695
# Epoch Number 3, Index = 24/31, Loss = 4.048779487609863
# Epoch Number 3, Index = 25/31, Loss = 3.6191940307617188
# Epoch Number 3, Index = 26/31, Loss = 4.148691177368164
# Epoch Number 3, Index = 27/31, Loss = 3.999439239501953
# Epoch Number 3, Index = 28/31, Loss = 4.090618133544922
# Epoch Number 3, Index = 29/31, Loss = 4.031695365905762
# Epoch Number 3, Index = 30/31, Loss = 4.0887651443481445
# Epoch Number 3, Index = 31/31, Loss = 4.039708137512207
# Accuracy on validation set: 9.509803921568627 %
# Epoch Number 4, Index = 0/31, Loss = 3.851253032684326
# Epoch Number 4, Index = 1/31, Loss = 3.8567981719970703
# Epoch Number 4, Index = 2/31, Loss = 4.092148780822754
# Epoch Number 4, Index = 3/31, Loss = 3.567683696746826
# Epoch Number 4, Index = 4/31, Loss = 3.825570583343506
# Epoch Number 4, Index = 5/31, Loss = 3.9704196453094482
# Epoch Number 4, Index = 6/31, Loss = 3.79647159576416
# Epoch Number 4, Index = 7/31, Loss = 3.7667224407196045
# Epoch Number 4, Index = 8/31, Loss = 3.7756526470184326
# Epoch Number 4, Index = 9/31, Loss = 4.205331802368164
# Epoch Number 4, Index = 10/31, Loss = 3.9380452632904053
# Epoch Number 4, Index = 11/31, Loss = 3.6277523040771484
# Epoch Number 4, Index = 12/31, Loss = 4.011919021606445
# Epoch Number 4, Index = 13/31, Loss = 3.6897244453430176
# Epoch Number 4, Index = 14/31, Loss = 3.586146831512451
# Epoch Number 4, Index = 15/31, Loss = 3.705681324005127
# Epoch Number 4, Index = 16/31, Loss = 3.910555362701416
# Epoch Number 4, Index = 17/31, Loss = 3.737396717071533
# Epoch Number 4, Index = 18/31, Loss = 3.652984619140625
# Epoch Number 4, Index = 19/31, Loss = 3.817361354827881
# Epoch Number 4, Index = 20/31, Loss = 3.754960060119629
# Epoch Number 4, Index = 21/31, Loss = 3.5650761127471924
# Epoch Number 4, Index = 22/31, Loss = 3.6408348083496094
# Epoch Number 4, Index = 23/31, Loss = 3.901411294937134
# Epoch Number 4, Index = 24/31, Loss = 3.872607469558716
# Epoch Number 4, Index = 25/31, Loss = 3.557257890701294
# Epoch Number 4, Index = 26/31, Loss = 3.785676956176758
# Epoch Number 4, Index = 27/31, Loss = 3.5853352546691895
# Epoch Number 4, Index = 28/31, Loss = 3.9068565368652344
# Epoch Number 4, Index = 29/31, Loss = 3.7662806510925293
# Epoch Number 4, Index = 30/31, Loss = 3.968235969543457
# Epoch Number 4, Index = 31/31, Loss = 3.92940092086792
# Accuracy on validation set: 13.03921568627451 %
# Epoch Number 5, Index = 0/31, Loss = 3.330143928527832
# Epoch Number 5, Index = 1/31, Loss = 3.7867727279663086
# Epoch Number 5, Index = 2/31, Loss = 3.7853617668151855
# Epoch Number 5, Index = 3/31, Loss = 3.432263135910034
# Epoch Number 5, Index = 4/31, Loss = 3.586493730545044
# Epoch Number 5, Index = 5/31, Loss = 3.173475503921509
# Epoch Number 5, Index = 6/31, Loss = 3.780517578125
# Epoch Number 5, Index = 7/31, Loss = 3.7445528507232666
# Epoch Number 5, Index = 8/31, Loss = 3.763519763946533
# Epoch Number 5, Index = 9/31, Loss = 3.5208981037139893
# Epoch Number 5, Index = 10/31, Loss = 3.7111520767211914
# Epoch Number 5, Index = 11/31, Loss = 3.530604839324951
# Epoch Number 5, Index = 12/31, Loss = 3.7843973636627197
# Epoch Number 5, Index = 13/31, Loss = 3.6287240982055664
# Epoch Number 5, Index = 14/31, Loss = 3.4455182552337646
# Epoch Number 5, Index = 15/31, Loss = 3.535013437271118
# Epoch Number 5, Index = 16/31, Loss = 3.5730128288269043
# Epoch Number 5, Index = 17/31, Loss = 3.546065330505371
# Epoch Number 5, Index = 18/31, Loss = 3.2447683811187744
# Epoch Number 5, Index = 19/31, Loss = 3.656738042831421
# Epoch Number 5, Index = 20/31, Loss = 3.4735665321350098
# Epoch Number 5, Index = 21/31, Loss = 3.6616742610931396
# Epoch Number 5, Index = 22/31, Loss = 3.675541639328003
# Epoch Number 5, Index = 23/31, Loss = 3.519812822341919
# Epoch Number 5, Index = 24/31, Loss = 3.3251123428344727
# Epoch Number 5, Index = 25/31, Loss = 3.587113380432129
# Epoch Number 5, Index = 26/31, Loss = 3.7575979232788086
# Epoch Number 5, Index = 27/31, Loss = 3.8177995681762695
# Epoch Number 5, Index = 28/31, Loss = 3.6631064414978027
# Epoch Number 5, Index = 29/31, Loss = 3.205636501312256
# Epoch Number 5, Index = 30/31, Loss = 3.5577988624572754
# Epoch Number 5, Index = 31/31, Loss = 3.626678466796875
# Accuracy on validation set: 14.607843137254902 %
# Epoch Number 6, Index = 0/31, Loss = 3.2995574474334717
# Epoch Number 6, Index = 1/31, Loss = 3.7065882682800293
# Epoch Number 6, Index = 2/31, Loss = 3.661715030670166
# Epoch Number 6, Index = 3/31, Loss = 3.30338191986084
# Epoch Number 6, Index = 4/31, Loss = 3.0661439895629883
# Epoch Number 6, Index = 5/31, Loss = 3.3643288612365723
# Epoch Number 6, Index = 6/31, Loss = 3.2956647872924805
# Epoch Number 6, Index = 7/31, Loss = 3.3799843788146973
# Epoch Number 6, Index = 8/31, Loss = 3.1326518058776855
# Epoch Number 6, Index = 9/31, Loss = 3.140927314758301
# Epoch Number 6, Index = 10/31, Loss = 3.8111181259155273
# Epoch Number 6, Index = 11/31, Loss = 3.391514778137207
# Epoch Number 6, Index = 12/31, Loss = 2.9220261573791504
# Epoch Number 6, Index = 13/31, Loss = 3.4893369674682617
# Epoch Number 6, Index = 14/31, Loss = 3.484977960586548
# Epoch Number 6, Index = 15/31, Loss = 3.454089641571045
# Epoch Number 6, Index = 16/31, Loss = 3.660888195037842
# Epoch Number 6, Index = 17/31, Loss = 3.5106735229492188
# Epoch Number 6, Index = 18/31, Loss = 3.5007357597351074
# Epoch Number 6, Index = 19/31, Loss = 3.0496246814727783
# Epoch Number 6, Index = 20/31, Loss = 3.1222805976867676
# Epoch Number 6, Index = 21/31, Loss = 3.5700881481170654
# Epoch Number 6, Index = 22/31, Loss = 3.434262752532959
# Epoch Number 6, Index = 23/31, Loss = 3.2304673194885254
# Epoch Number 6, Index = 24/31, Loss = 3.2145493030548096
# Epoch Number 6, Index = 25/31, Loss = 3.404452323913574
# Epoch Number 6, Index = 26/31, Loss = 3.585658550262451
# Epoch Number 6, Index = 27/31, Loss = 3.416217803955078
# Epoch Number 6, Index = 28/31, Loss = 3.5232224464416504
# Epoch Number 6, Index = 29/31, Loss = 3.709313154220581
# Epoch Number 6, Index = 30/31, Loss = 3.3359766006469727
# Epoch Number 6, Index = 31/31, Loss = 3.533303737640381
# Accuracy on validation set: 17.647058823529413 %
# Epoch Number 7, Index = 0/31, Loss = 3.121476650238037
# Epoch Number 7, Index = 1/31, Loss = 3.2319693565368652
# Epoch Number 7, Index = 2/31, Loss = 3.480741262435913
# Epoch Number 7, Index = 3/31, Loss = 3.8049709796905518
# Epoch Number 7, Index = 4/31, Loss = 2.9683022499084473
# Epoch Number 7, Index = 5/31, Loss = 3.1150166988372803
# Epoch Number 7, Index = 6/31, Loss = 3.1415371894836426
# Epoch Number 7, Index = 7/31, Loss = 3.433253288269043
# Epoch Number 7, Index = 8/31, Loss = 3.082683563232422
# Epoch Number 7, Index = 9/31, Loss = 2.777190685272217
# Epoch Number 7, Index = 10/31, Loss = 3.258971691131592
# Epoch Number 7, Index = 11/31, Loss = 3.117260456085205
# Epoch Number 7, Index = 12/31, Loss = 3.329512357711792
# Epoch Number 7, Index = 13/31, Loss = 3.73738431930542
# Epoch Number 7, Index = 14/31, Loss = 3.2803807258605957
# Epoch Number 7, Index = 15/31, Loss = 2.9791147708892822
# Epoch Number 7, Index = 16/31, Loss = 3.3754429817199707
# Epoch Number 7, Index = 17/31, Loss = 3.2311511039733887
# Epoch Number 7, Index = 18/31, Loss = 2.9763190746307373
# Epoch Number 7, Index = 19/31, Loss = 3.508890151977539
# Epoch Number 7, Index = 20/31, Loss = 3.180387496948242
# Epoch Number 7, Index = 21/31, Loss = 3.404683828353882
# Epoch Number 7, Index = 22/31, Loss = 3.0946760177612305
# Epoch Number 7, Index = 23/31, Loss = 3.3560404777526855
# Epoch Number 7, Index = 24/31, Loss = 3.183411121368408
# Epoch Number 7, Index = 25/31, Loss = 3.2470505237579346
# Epoch Number 7, Index = 26/31, Loss = 3.2078657150268555
# Epoch Number 7, Index = 27/31, Loss = 3.421158790588379
# Epoch Number 7, Index = 28/31, Loss = 3.1569104194641113
# Epoch Number 7, Index = 29/31, Loss = 3.247006416320801
# Epoch Number 7, Index = 30/31, Loss = 3.1860408782958984
# Epoch Number 7, Index = 31/31, Loss = 2.9977118968963623
# Accuracy on validation set: 19.11764705882353 %
# Epoch Number 8, Index = 0/31, Loss = 3.097404956817627
# Epoch Number 8, Index = 1/31, Loss = 3.143172264099121
# Epoch Number 8, Index = 2/31, Loss = 3.1201963424682617
# Epoch Number 8, Index = 3/31, Loss = 3.3960213661193848
# Epoch Number 8, Index = 4/31, Loss = 3.243417739868164
# Epoch Number 8, Index = 5/31, Loss = 3.227383852005005
# Epoch Number 8, Index = 6/31, Loss = 3.322096824645996
# Epoch Number 8, Index = 7/31, Loss = 2.9436380863189697
# Epoch Number 8, Index = 8/31, Loss = 3.21077561378479
# Epoch Number 8, Index = 9/31, Loss = 3.4799370765686035
# Epoch Number 8, Index = 10/31, Loss = 3.4349417686462402
# Epoch Number 8, Index = 11/31, Loss = 2.8888444900512695
# Epoch Number 8, Index = 12/31, Loss = 3.048663854598999
# Epoch Number 8, Index = 13/31, Loss = 2.751192569732666
# Epoch Number 8, Index = 14/31, Loss = 3.3374476432800293
# Epoch Number 8, Index = 15/31, Loss = 3.2227089405059814
# Epoch Number 8, Index = 16/31, Loss = 3.539018154144287
# Epoch Number 8, Index = 17/31, Loss = 2.8435468673706055
# Epoch Number 8, Index = 18/31, Loss = 3.5225231647491455
# Epoch Number 8, Index = 19/31, Loss = 3.0378689765930176
# Epoch Number 8, Index = 20/31, Loss = 2.8623762130737305
# Epoch Number 8, Index = 21/31, Loss = 3.1817898750305176
# Epoch Number 8, Index = 22/31, Loss = 3.3696651458740234
# Epoch Number 8, Index = 23/31, Loss = 2.914088010787964
# Epoch Number 8, Index = 24/31, Loss = 2.9755163192749023
# Epoch Number 8, Index = 25/31, Loss = 3.0495684146881104
# Epoch Number 8, Index = 26/31, Loss = 2.8759453296661377
# Epoch Number 8, Index = 27/31, Loss = 3.0144143104553223
# Epoch Number 8, Index = 28/31, Loss = 2.9848179817199707
# Epoch Number 8, Index = 29/31, Loss = 3.2731454372406006
# Epoch Number 8, Index = 30/31, Loss = 2.902299404144287
# Epoch Number 8, Index = 31/31, Loss = 3.01942777633667
# Accuracy on validation set: 21.470588235294116 %
# Epoch Number 9, Index = 0/31, Loss = 2.9392647743225098
# Epoch Number 9, Index = 1/31, Loss = 3.224853515625
# Epoch Number 9, Index = 2/31, Loss = 2.788651466369629
# Epoch Number 9, Index = 3/31, Loss = 3.0533416271209717
# Epoch Number 9, Index = 4/31, Loss = 2.7689661979675293
# Epoch Number 9, Index = 5/31, Loss = 2.951141357421875
# Epoch Number 9, Index = 6/31, Loss = 3.3269200325012207
# Epoch Number 9, Index = 7/31, Loss = 2.5293922424316406
# Epoch Number 9, Index = 8/31, Loss = 2.9234790802001953
# Epoch Number 9, Index = 9/31, Loss = 3.122643232345581
# Epoch Number 9, Index = 10/31, Loss = 3.108613967895508
# Epoch Number 9, Index = 11/31, Loss = 2.781989574432373
# Epoch Number 9, Index = 12/31, Loss = 2.5924723148345947
# Epoch Number 9, Index = 13/31, Loss = 3.1365888118743896
# Epoch Number 9, Index = 14/31, Loss = 3.1232218742370605
# Epoch Number 9, Index = 15/31, Loss = 3.065406322479248
# Epoch Number 9, Index = 16/31, Loss = 3.1259818077087402
# Epoch Number 9, Index = 17/31, Loss = 2.7153401374816895
# Epoch Number 9, Index = 18/31, Loss = 3.0434603691101074
# Epoch Number 9, Index = 19/31, Loss = 3.1316280364990234
# Epoch Number 9, Index = 20/31, Loss = 3.3906302452087402
# Epoch Number 9, Index = 21/31, Loss = 3.258049249649048
# Epoch Number 9, Index = 22/31, Loss = 3.2167792320251465
# Epoch Number 9, Index = 23/31, Loss = 2.8140006065368652
# Epoch Number 9, Index = 24/31, Loss = 3.0221989154815674
# Epoch Number 9, Index = 25/31, Loss = 2.892975330352783
# Epoch Number 9, Index = 26/31, Loss = 2.8099803924560547
# Epoch Number 9, Index = 27/31, Loss = 3.1701436042785645
# Epoch Number 9, Index = 28/31, Loss = 2.9981441497802734
# Epoch Number 9, Index = 29/31, Loss = 2.8734049797058105
# Epoch Number 9, Index = 30/31, Loss = 3.258586883544922
# Epoch Number 9, Index = 31/31, Loss = 3.023139476776123
# Accuracy on validation set: 18.92156862745098 %
# Epoch Number 10, Index = 0/31, Loss = 2.6308369636535645
# Epoch Number 10, Index = 1/31, Loss = 2.988558769226074
# Epoch Number 10, Index = 2/31, Loss = 2.627472400665283
# Epoch Number 10, Index = 3/31, Loss = 3.148282051086426
# Epoch Number 10, Index = 4/31, Loss = 2.7857666015625
# Epoch Number 10, Index = 5/31, Loss = 2.8912112712860107
# Epoch Number 10, Index = 6/31, Loss = 3.4006261825561523
# Epoch Number 10, Index = 7/31, Loss = 3.261140823364258
# Epoch Number 10, Index = 8/31, Loss = 3.1957364082336426
# Epoch Number 10, Index = 9/31, Loss = 2.675339698791504
# Epoch Number 10, Index = 10/31, Loss = 2.772264003753662
# Epoch Number 10, Index = 11/31, Loss = 3.038959503173828
# Epoch Number 10, Index = 12/31, Loss = 2.697277545928955
# Epoch Number 10, Index = 13/31, Loss = 3.151233673095703
# Epoch Number 10, Index = 14/31, Loss = 3.1274752616882324
# Epoch Number 10, Index = 15/31, Loss = 3.262455940246582
# Epoch Number 10, Index = 16/31, Loss = 2.8536412715911865
# Epoch Number 10, Index = 17/31, Loss = 2.5998191833496094
# Epoch Number 10, Index = 18/31, Loss = 3.1612839698791504
# Epoch Number 10, Index = 19/31, Loss = 2.790121078491211
# Epoch Number 10, Index = 20/31, Loss = 2.9350528717041016
# Epoch Number 10, Index = 21/31, Loss = 3.0277090072631836
# Epoch Number 10, Index = 22/31, Loss = 2.8389439582824707
# Epoch Number 10, Index = 23/31, Loss = 3.0832953453063965
# Epoch Number 10, Index = 24/31, Loss = 2.98237681388855
# Epoch Number 10, Index = 25/31, Loss = 2.668613910675049
# Epoch Number 10, Index = 26/31, Loss = 2.645817279815674
# Epoch Number 10, Index = 27/31, Loss = 2.977234125137329
# Epoch Number 10, Index = 28/31, Loss = 2.9100146293640137
# Epoch Number 10, Index = 29/31, Loss = 2.543118476867676
# Epoch Number 10, Index = 30/31, Loss = 2.7292861938476562
# Epoch Number 10, Index = 31/31, Loss = 3.0879628658294678
# Accuracy on validation set: 23.235294117647058 %
# Epoch Number 11, Index = 0/31, Loss = 2.773854970932007
# Epoch Number 11, Index = 1/31, Loss = 2.9774651527404785
# Epoch Number 11, Index = 2/31, Loss = 2.8243184089660645
# Epoch Number 11, Index = 3/31, Loss = 2.9601707458496094
# Epoch Number 11, Index = 4/31, Loss = 2.503727912902832
# Epoch Number 11, Index = 5/31, Loss = 2.490788459777832
# Epoch Number 11, Index = 6/31, Loss = 2.925724506378174
# Epoch Number 11, Index = 7/31, Loss = 3.027627944946289
# Epoch Number 11, Index = 8/31, Loss = 2.743891716003418
# Epoch Number 11, Index = 9/31, Loss = 2.4924850463867188
# Epoch Number 11, Index = 10/31, Loss = 2.791482448577881
# Epoch Number 11, Index = 11/31, Loss = 2.9000604152679443
# Epoch Number 11, Index = 12/31, Loss = 2.651838779449463
# Epoch Number 11, Index = 13/31, Loss = 3.0175514221191406
# Epoch Number 11, Index = 14/31, Loss = 2.944887399673462
# Epoch Number 11, Index = 15/31, Loss = 2.569352626800537
# Epoch Number 11, Index = 16/31, Loss = 2.9020118713378906
# Epoch Number 11, Index = 17/31, Loss = 2.8245620727539062
# Epoch Number 11, Index = 18/31, Loss = 2.6061129570007324
# Epoch Number 11, Index = 19/31, Loss = 3.012907028198242
# Epoch Number 11, Index = 20/31, Loss = 2.7823686599731445
# Epoch Number 11, Index = 21/31, Loss = 2.956021308898926
# Epoch Number 11, Index = 22/31, Loss = 3.1055281162261963
# Epoch Number 11, Index = 23/31, Loss = 2.695751905441284
# Epoch Number 11, Index = 24/31, Loss = 2.7016193866729736
# Epoch Number 11, Index = 25/31, Loss = 2.572077751159668
# Epoch Number 11, Index = 26/31, Loss = 3.0090808868408203
# Epoch Number 11, Index = 27/31, Loss = 3.3822193145751953
# Epoch Number 11, Index = 28/31, Loss = 3.000642776489258
# Epoch Number 11, Index = 29/31, Loss = 3.326409101486206
# Epoch Number 11, Index = 30/31, Loss = 3.226367950439453
# Epoch Number 11, Index = 31/31, Loss = 2.719823122024536
# Accuracy on validation set: 24.705882352941178 %
# Epoch Number 12, Index = 0/31, Loss = 2.354681968688965
# Epoch Number 12, Index = 1/31, Loss = 3.105997323989868
# Epoch Number 12, Index = 2/31, Loss = 2.905691623687744
# Epoch Number 12, Index = 3/31, Loss = 2.799943447113037
# Epoch Number 12, Index = 4/31, Loss = 2.991086006164551
# Epoch Number 12, Index = 5/31, Loss = 2.6810789108276367
# Epoch Number 12, Index = 6/31, Loss = 2.6616599559783936
# Epoch Number 12, Index = 7/31, Loss = 2.9343857765197754
# Epoch Number 12, Index = 8/31, Loss = 2.6976146697998047
# Epoch Number 12, Index = 9/31, Loss = 2.3514413833618164
# Epoch Number 12, Index = 10/31, Loss = 2.6584649085998535
# Epoch Number 12, Index = 11/31, Loss = 2.656275510787964
# Epoch Number 12, Index = 12/31, Loss = 3.0495707988739014
# Epoch Number 12, Index = 13/31, Loss = 3.0304696559906006
# Epoch Number 12, Index = 14/31, Loss = 2.9989609718322754
# Epoch Number 12, Index = 15/31, Loss = 2.535600185394287
# Epoch Number 12, Index = 16/31, Loss = 2.387392997741699
# Epoch Number 12, Index = 17/31, Loss = 2.707291603088379
# Epoch Number 12, Index = 18/31, Loss = 3.293576240539551
# Epoch Number 12, Index = 19/31, Loss = 2.651745319366455
# Epoch Number 12, Index = 20/31, Loss = 2.6590144634246826
# Epoch Number 12, Index = 21/31, Loss = 2.520555019378662
# Epoch Number 12, Index = 22/31, Loss = 2.2872061729431152
# Epoch Number 12, Index = 23/31, Loss = 2.7877800464630127
# Epoch Number 12, Index = 24/31, Loss = 2.7698800563812256
# Epoch Number 12, Index = 25/31, Loss = 2.6584010124206543
# Epoch Number 12, Index = 26/31, Loss = 2.498641014099121
# Epoch Number 12, Index = 27/31, Loss = 2.849860429763794
# Epoch Number 12, Index = 28/31, Loss = 3.2560362815856934
# Epoch Number 12, Index = 29/31, Loss = 2.863027334213257
# Epoch Number 12, Index = 30/31, Loss = 3.9517130851745605
# Epoch Number 12, Index = 31/31, Loss = 2.5614192485809326
# Accuracy on validation set: 23.92156862745098 %
# Epoch Number 13, Index = 0/31, Loss = 2.5588130950927734
# Epoch Number 13, Index = 1/31, Loss = 3.1043615341186523
# Epoch Number 13, Index = 2/31, Loss = 2.9139256477355957
# Epoch Number 13, Index = 3/31, Loss = 2.445711612701416
# Epoch Number 13, Index = 4/31, Loss = 2.882704734802246
# Epoch Number 13, Index = 5/31, Loss = 2.3693580627441406
# Epoch Number 13, Index = 6/31, Loss = 2.7838399410247803
# Epoch Number 13, Index = 7/31, Loss = 2.6386923789978027
# Epoch Number 13, Index = 8/31, Loss = 2.721250534057617
# Epoch Number 13, Index = 9/31, Loss = 3.0575881004333496
# Epoch Number 13, Index = 10/31, Loss = 2.548093318939209
# Epoch Number 13, Index = 11/31, Loss = 2.714205503463745
# Epoch Number 13, Index = 12/31, Loss = 2.948385715484619
# Epoch Number 13, Index = 13/31, Loss = 2.7477469444274902
# Epoch Number 13, Index = 14/31, Loss = 2.6197714805603027
# Epoch Number 13, Index = 15/31, Loss = 2.2635834217071533
# Epoch Number 13, Index = 16/31, Loss = 2.98170804977417
# Epoch Number 13, Index = 17/31, Loss = 2.866156816482544
# Epoch Number 13, Index = 18/31, Loss = 2.531048059463501
# Epoch Number 13, Index = 19/31, Loss = 2.6751108169555664
# Epoch Number 13, Index = 20/31, Loss = 2.6614489555358887
# Epoch Number 13, Index = 21/31, Loss = 2.57253098487854
# Epoch Number 13, Index = 22/31, Loss = 2.7985000610351562
# Epoch Number 13, Index = 23/31, Loss = 2.3140532970428467
# Epoch Number 13, Index = 24/31, Loss = 2.66758394241333
# Epoch Number 13, Index = 25/31, Loss = 2.714817523956299
# Epoch Number 13, Index = 26/31, Loss = 2.472795009613037
# Epoch Number 13, Index = 27/31, Loss = 2.860106945037842
# Epoch Number 13, Index = 28/31, Loss = 2.6229403018951416
# Epoch Number 13, Index = 29/31, Loss = 2.8804173469543457
# Epoch Number 13, Index = 30/31, Loss = 2.6282315254211426
# Epoch Number 13, Index = 31/31, Loss = 2.7398314476013184
# Accuracy on validation set: 24.901960784313726 %
# Epoch Number 14, Index = 0/31, Loss = 2.536949634552002
# Epoch Number 14, Index = 1/31, Loss = 2.73538875579834
# Epoch Number 14, Index = 2/31, Loss = 2.188019037246704
# Epoch Number 14, Index = 3/31, Loss = 3.1955995559692383
# Epoch Number 14, Index = 4/31, Loss = 2.851966381072998
# Epoch Number 14, Index = 5/31, Loss = 2.576958179473877
# Epoch Number 14, Index = 6/31, Loss = 2.9282455444335938
# Epoch Number 14, Index = 7/31, Loss = 2.489919424057007
# Epoch Number 14, Index = 8/31, Loss = 2.412903070449829
# Epoch Number 14, Index = 9/31, Loss = 2.9629158973693848
# Epoch Number 14, Index = 10/31, Loss = 2.6500258445739746
# Epoch Number 14, Index = 11/31, Loss = 2.5904483795166016
# Epoch Number 14, Index = 12/31, Loss = 2.6669628620147705
# Epoch Number 14, Index = 13/31, Loss = 2.2339301109313965
# Epoch Number 14, Index = 14/31, Loss = 1.8485344648361206
# Epoch Number 14, Index = 15/31, Loss = 2.5207605361938477
# Epoch Number 14, Index = 16/31, Loss = 2.5396032333374023
# Epoch Number 14, Index = 17/31, Loss = 3.2203798294067383
# Epoch Number 14, Index = 18/31, Loss = 2.112292766571045
# Epoch Number 14, Index = 19/31, Loss = 2.780061721801758
# Epoch Number 14, Index = 20/31, Loss = 2.6426727771759033
# Epoch Number 14, Index = 21/31, Loss = 2.5514769554138184
# Epoch Number 14, Index = 22/31, Loss = 2.9254238605499268
# Epoch Number 14, Index = 23/31, Loss = 2.6958937644958496
# Epoch Number 14, Index = 24/31, Loss = 2.777228832244873
# Epoch Number 14, Index = 25/31, Loss = 2.634066104888916
# Epoch Number 14, Index = 26/31, Loss = 2.4494612216949463
# Epoch Number 14, Index = 27/31, Loss = 2.4902920722961426
# Epoch Number 14, Index = 28/31, Loss = 2.5545601844787598
# Epoch Number 14, Index = 29/31, Loss = 2.4654550552368164
# Epoch Number 14, Index = 30/31, Loss = 2.455700159072876
# Epoch Number 14, Index = 31/31, Loss = 2.4475910663604736
# Accuracy on validation set: 24.215686274509803 %
# Epoch Number 15, Index = 0/31, Loss = 2.2698073387145996
# Epoch Number 15, Index = 1/31, Loss = 2.7953124046325684
# Epoch Number 15, Index = 2/31, Loss = 2.8172106742858887
# Epoch Number 15, Index = 3/31, Loss = 2.6599788665771484
# Epoch Number 15, Index = 4/31, Loss = 2.3370814323425293
# Epoch Number 15, Index = 5/31, Loss = 2.241985321044922
# Epoch Number 15, Index = 6/31, Loss = 2.7953524589538574
# Epoch Number 15, Index = 7/31, Loss = 2.4049606323242188
# Epoch Number 15, Index = 8/31, Loss = 2.986325263977051
# Epoch Number 15, Index = 9/31, Loss = 2.515151023864746
# Epoch Number 15, Index = 10/31, Loss = 3.0063955783843994
# Epoch Number 15, Index = 11/31, Loss = 2.432990789413452
# Epoch Number 15, Index = 12/31, Loss = 3.005587100982666
# Epoch Number 15, Index = 13/31, Loss = 2.381181240081787
# Epoch Number 15, Index = 14/31, Loss = 2.6816344261169434
# Epoch Number 15, Index = 15/31, Loss = 2.469956874847412
# Epoch Number 15, Index = 16/31, Loss = 2.0571603775024414
# Epoch Number 15, Index = 17/31, Loss = 2.3497002124786377
# Epoch Number 15, Index = 18/31, Loss = 2.4848735332489014
# Epoch Number 15, Index = 19/31, Loss = 2.2409183979034424
# Epoch Number 15, Index = 20/31, Loss = 2.7348792552948
# Epoch Number 15, Index = 21/31, Loss = 2.676527261734009
# Epoch Number 15, Index = 22/31, Loss = 2.8632116317749023
# Epoch Number 15, Index = 23/31, Loss = 2.151155948638916
# Epoch Number 15, Index = 24/31, Loss = 2.2918341159820557
# Epoch Number 15, Index = 25/31, Loss = 2.686710834503174
# Epoch Number 15, Index = 26/31, Loss = 2.673891067504883
# Epoch Number 15, Index = 27/31, Loss = 2.8609235286712646
# Epoch Number 15, Index = 28/31, Loss = 2.038886070251465
# Epoch Number 15, Index = 29/31, Loss = 2.2619128227233887
# Epoch Number 15, Index = 30/31, Loss = 2.631399393081665
# Epoch Number 15, Index = 31/31, Loss = 2.7383506298065186
# Accuracy on validation set: 25.980392156862745 %
# Epoch Number 16, Index = 0/31, Loss = 2.7519497871398926
# Epoch Number 16, Index = 1/31, Loss = 2.012310266494751
# Epoch Number 16, Index = 2/31, Loss = 2.3778467178344727
# Epoch Number 16, Index = 3/31, Loss = 2.3892741203308105
# Epoch Number 16, Index = 4/31, Loss = 2.263265609741211
# Epoch Number 16, Index = 5/31, Loss = 2.842973232269287
# Epoch Number 16, Index = 6/31, Loss = 2.4723007678985596
# Epoch Number 16, Index = 7/31, Loss = 2.373734474182129
# Epoch Number 16, Index = 8/31, Loss = 2.6723427772521973
# Epoch Number 16, Index = 9/31, Loss = 2.401642322540283
# Epoch Number 16, Index = 10/31, Loss = 2.481156826019287
# Epoch Number 16, Index = 11/31, Loss = 2.788980484008789
# Epoch Number 16, Index = 12/31, Loss = 2.599478244781494
# Epoch Number 16, Index = 13/31, Loss = 2.2997636795043945
# Epoch Number 16, Index = 14/31, Loss = 2.411172866821289
# Epoch Number 16, Index = 15/31, Loss = 2.300795793533325
# Epoch Number 16, Index = 16/31, Loss = 2.1815009117126465
# Epoch Number 16, Index = 17/31, Loss = 1.9175655841827393
# Epoch Number 16, Index = 18/31, Loss = 2.5069289207458496
# Epoch Number 16, Index = 19/31, Loss = 2.4087982177734375
# Epoch Number 16, Index = 20/31, Loss = 2.9393491744995117
# Epoch Number 16, Index = 21/31, Loss = 2.298457145690918
# Epoch Number 16, Index = 22/31, Loss = 2.6405537128448486
# Epoch Number 16, Index = 23/31, Loss = 2.5997185707092285
# Epoch Number 16, Index = 24/31, Loss = 2.746378183364868
# Epoch Number 16, Index = 25/31, Loss = 2.5141305923461914
# Epoch Number 16, Index = 26/31, Loss = 2.200160264968872
# Epoch Number 16, Index = 27/31, Loss = 2.4237964153289795
# Epoch Number 16, Index = 28/31, Loss = 2.4561915397644043
# Epoch Number 16, Index = 29/31, Loss = 2.288247585296631
# Epoch Number 16, Index = 30/31, Loss = 2.533491373062134
# Epoch Number 16, Index = 31/31, Loss = 2.3215556144714355
# Accuracy on validation set: 27.647058823529413 %
# Epoch Number 17, Index = 0/31, Loss = 2.0461275577545166
# Epoch Number 17, Index = 1/31, Loss = 1.5667214393615723
# Epoch Number 17, Index = 2/31, Loss = 2.9263010025024414
# Epoch Number 17, Index = 3/31, Loss = 2.110041379928589
# Epoch Number 17, Index = 4/31, Loss = 2.4856040477752686
# Epoch Number 17, Index = 5/31, Loss = 2.701676607131958
# Epoch Number 17, Index = 6/31, Loss = 1.8961467742919922
# Epoch Number 17, Index = 7/31, Loss = 1.987180233001709
# Epoch Number 17, Index = 8/31, Loss = 2.2718071937561035
# Epoch Number 17, Index = 9/31, Loss = 2.101834297180176
# Epoch Number 17, Index = 10/31, Loss = 2.467607021331787
# Epoch Number 17, Index = 11/31, Loss = 2.5794801712036133
# Epoch Number 17, Index = 12/31, Loss = 2.0018773078918457
# Epoch Number 17, Index = 13/31, Loss = 2.673755168914795
# Epoch Number 17, Index = 14/31, Loss = 2.220189094543457
# Epoch Number 17, Index = 15/31, Loss = 2.1480870246887207
# Epoch Number 17, Index = 16/31, Loss = 2.447606086730957
# Epoch Number 17, Index = 17/31, Loss = 2.158426284790039
# Epoch Number 17, Index = 18/31, Loss = 2.6125051975250244
# Epoch Number 17, Index = 19/31, Loss = 1.9086592197418213
# Epoch Number 17, Index = 20/31, Loss = 2.5021402835845947
# Epoch Number 17, Index = 21/31, Loss = 2.5842113494873047
# Epoch Number 17, Index = 22/31, Loss = 2.740190029144287
# Epoch Number 17, Index = 23/31, Loss = 2.4586172103881836
# Epoch Number 17, Index = 24/31, Loss = 2.135904312133789
# Epoch Number 17, Index = 25/31, Loss = 2.459940195083618
# Epoch Number 17, Index = 26/31, Loss = 2.4326376914978027
# Epoch Number 17, Index = 27/31, Loss = 2.2989747524261475
# Epoch Number 17, Index = 28/31, Loss = 2.6214590072631836
# Epoch Number 17, Index = 29/31, Loss = 2.2901992797851562
# Epoch Number 17, Index = 30/31, Loss = 1.7100706100463867
# Epoch Number 17, Index = 31/31, Loss = 3.209827423095703
# Accuracy on validation set: 27.54901960784314 %
# Epoch Number 18, Index = 0/31, Loss = 2.568448543548584
# Epoch Number 18, Index = 1/31, Loss = 1.912500023841858
# Epoch Number 18, Index = 2/31, Loss = 2.433187246322632
# Epoch Number 18, Index = 3/31, Loss = 2.342189311981201
# Epoch Number 18, Index = 4/31, Loss = 1.9743622541427612
# Epoch Number 18, Index = 5/31, Loss = 2.34961199760437
# Epoch Number 18, Index = 6/31, Loss = 2.7166590690612793
# Epoch Number 18, Index = 7/31, Loss = 2.608741521835327
# Epoch Number 18, Index = 8/31, Loss = 2.683089256286621
# Epoch Number 18, Index = 9/31, Loss = 2.4420690536499023
# Epoch Number 18, Index = 10/31, Loss = 2.556614637374878
# Epoch Number 18, Index = 11/31, Loss = 2.476362705230713
# Epoch Number 18, Index = 12/31, Loss = 2.3528549671173096
# Epoch Number 18, Index = 13/31, Loss = 2.0424253940582275
# Epoch Number 18, Index = 14/31, Loss = 2.191406011581421
# Epoch Number 18, Index = 15/31, Loss = 2.2800302505493164
# Epoch Number 18, Index = 16/31, Loss = 2.2613587379455566
# Epoch Number 18, Index = 17/31, Loss = 2.5202932357788086
# Epoch Number 18, Index = 18/31, Loss = 2.436980724334717
# Epoch Number 18, Index = 19/31, Loss = 2.4502859115600586
# Epoch Number 18, Index = 20/31, Loss = 2.034480571746826
# Epoch Number 18, Index = 21/31, Loss = 2.6446144580841064
# Epoch Number 18, Index = 22/31, Loss = 2.726897716522217
# Epoch Number 18, Index = 23/31, Loss = 2.0643727779388428
# Epoch Number 18, Index = 24/31, Loss = 2.5725531578063965
# Epoch Number 18, Index = 25/31, Loss = 2.0709004402160645
# Epoch Number 18, Index = 26/31, Loss = 2.277219772338867
# Epoch Number 18, Index = 27/31, Loss = 2.3733487129211426
# Epoch Number 18, Index = 28/31, Loss = 2.3597676753997803
# Epoch Number 18, Index = 29/31, Loss = 2.2070491313934326
# Epoch Number 18, Index = 30/31, Loss = 2.296783685684204
# Epoch Number 18, Index = 31/31, Loss = 2.3871586322784424
# Accuracy on validation set: 27.254901960784313 %
# Epoch Number 19, Index = 0/31, Loss = 1.8968485593795776
# Epoch Number 19, Index = 1/31, Loss = 2.150557041168213
# Epoch Number 19, Index = 2/31, Loss = 1.815521478652954
# Epoch Number 19, Index = 3/31, Loss = 2.1303467750549316
# Epoch Number 19, Index = 4/31, Loss = 2.073599338531494
# Epoch Number 19, Index = 5/31, Loss = 2.4403629302978516
# Epoch Number 19, Index = 6/31, Loss = 2.7593278884887695
# Epoch Number 19, Index = 7/31, Loss = 2.443774700164795
# Epoch Number 19, Index = 8/31, Loss = 2.4852161407470703
# Epoch Number 19, Index = 9/31, Loss = 2.219675064086914
# Epoch Number 19, Index = 10/31, Loss = 2.161806106567383
# Epoch Number 19, Index = 11/31, Loss = 2.132309913635254
# Epoch Number 19, Index = 12/31, Loss = 1.8846156597137451
# Epoch Number 19, Index = 13/31, Loss = 2.6412291526794434
# Epoch Number 19, Index = 14/31, Loss = 2.322594404220581
# Epoch Number 19, Index = 15/31, Loss = 2.0640182495117188
# Epoch Number 19, Index = 16/31, Loss = 2.2476141452789307
# Epoch Number 19, Index = 17/31, Loss = 2.5591683387756348
# Epoch Number 19, Index = 18/31, Loss = 2.372494697570801
# Epoch Number 19, Index = 19/31, Loss = 2.079261302947998
# Epoch Number 19, Index = 20/31, Loss = 1.9051896333694458
# Epoch Number 19, Index = 21/31, Loss = 2.215254068374634
# Epoch Number 19, Index = 22/31, Loss = 2.2699742317199707
# Epoch Number 19, Index = 23/31, Loss = 2.1684069633483887
# Epoch Number 19, Index = 24/31, Loss = 2.2546257972717285
# Epoch Number 19, Index = 25/31, Loss = 2.262728214263916
# Epoch Number 19, Index = 26/31, Loss = 2.5382752418518066
# Epoch Number 19, Index = 27/31, Loss = 2.4188647270202637
# Epoch Number 19, Index = 28/31, Loss = 1.9488276243209839
# Epoch Number 19, Index = 29/31, Loss = 2.4507462978363037
# Epoch Number 19, Index = 30/31, Loss = 2.097614288330078
# Epoch Number 19, Index = 31/31, Loss = 1.8431452512741089
# Accuracy on validation set: 29.019607843137255 %
# Epoch Number 20, Index = 0/31, Loss = 1.8241819143295288
# Epoch Number 20, Index = 1/31, Loss = 2.111051559448242
# Epoch Number 20, Index = 2/31, Loss = 2.0353636741638184
# Epoch Number 20, Index = 3/31, Loss = 2.6058382987976074
# Epoch Number 20, Index = 4/31, Loss = 1.9860951900482178
# Epoch Number 20, Index = 5/31, Loss = 2.5434751510620117
# Epoch Number 20, Index = 6/31, Loss = 2.0005784034729004
# Epoch Number 20, Index = 7/31, Loss = 2.0819969177246094
# Epoch Number 20, Index = 8/31, Loss = 2.417985439300537
# Epoch Number 20, Index = 9/31, Loss = 1.8256473541259766
# Epoch Number 20, Index = 10/31, Loss = 2.2778782844543457
# Epoch Number 20, Index = 11/31, Loss = 2.1067001819610596
# Epoch Number 20, Index = 12/31, Loss = 2.5773370265960693
# Epoch Number 20, Index = 13/31, Loss = 2.184112071990967
# Epoch Number 20, Index = 14/31, Loss = 2.4925289154052734
# Epoch Number 20, Index = 15/31, Loss = 2.298997640609741
# Epoch Number 20, Index = 16/31, Loss = 2.2696871757507324
# Epoch Number 20, Index = 17/31, Loss = 1.8496081829071045
# Epoch Number 20, Index = 18/31, Loss = 1.8907222747802734
# Epoch Number 20, Index = 19/31, Loss = 2.1285128593444824
# Epoch Number 20, Index = 20/31, Loss = 2.263948440551758
# Epoch Number 20, Index = 21/31, Loss = 2.0988361835479736
# Epoch Number 20, Index = 22/31, Loss = 1.7465310096740723
# Epoch Number 20, Index = 23/31, Loss = 2.1762380599975586
# Epoch Number 20, Index = 24/31, Loss = 2.4716272354125977
# Epoch Number 20, Index = 25/31, Loss = 2.29691743850708
# Epoch Number 20, Index = 26/31, Loss = 2.4565725326538086
# Epoch Number 20, Index = 27/31, Loss = 2.0047340393066406
# Epoch Number 20, Index = 28/31, Loss = 1.8530325889587402
# Epoch Number 20, Index = 29/31, Loss = 2.1175031661987305
# Epoch Number 20, Index = 30/31, Loss = 2.1919572353363037
# Epoch Number 20, Index = 31/31, Loss = 2.4171481132507324
# Accuracy on validation set: 27.84313725490196 %
# Epoch Number 21, Index = 0/31, Loss = 1.8467270135879517
# Epoch Number 21, Index = 1/31, Loss = 2.247182607650757
# Epoch Number 21, Index = 2/31, Loss = 2.380262851715088
# Epoch Number 21, Index = 3/31, Loss = 2.222226142883301
# Epoch Number 21, Index = 4/31, Loss = 1.9271085262298584
# Epoch Number 21, Index = 5/31, Loss = 2.0111680030822754
# Epoch Number 21, Index = 6/31, Loss = 2.2246830463409424
# Epoch Number 21, Index = 7/31, Loss = 1.9624731540679932
# Epoch Number 21, Index = 8/31, Loss = 2.345519781112671
# Epoch Number 21, Index = 9/31, Loss = 1.8247754573822021
# Epoch Number 21, Index = 10/31, Loss = 2.3934884071350098
# Epoch Number 21, Index = 11/31, Loss = 2.2302634716033936
# Epoch Number 21, Index = 12/31, Loss = 2.000446319580078
# Epoch Number 21, Index = 13/31, Loss = 1.8913655281066895
# Epoch Number 21, Index = 14/31, Loss = 2.15708065032959
# Epoch Number 21, Index = 15/31, Loss = 2.27956485748291
# Epoch Number 21, Index = 16/31, Loss = 2.4372668266296387
# Epoch Number 21, Index = 17/31, Loss = 1.8859113454818726
# Epoch Number 21, Index = 18/31, Loss = 1.8856050968170166
# Epoch Number 21, Index = 19/31, Loss = 1.9384311437606812
# Epoch Number 21, Index = 20/31, Loss = 2.0263924598693848
# Epoch Number 21, Index = 21/31, Loss = 2.4190425872802734
# Epoch Number 21, Index = 22/31, Loss = 2.1221094131469727
# Epoch Number 21, Index = 23/31, Loss = 1.825425386428833
# Epoch Number 21, Index = 24/31, Loss = 2.2008447647094727
# Epoch Number 21, Index = 25/31, Loss = 1.9715731143951416
# Epoch Number 21, Index = 26/31, Loss = 2.3000564575195312
# Epoch Number 21, Index = 27/31, Loss = 2.403533935546875
# Epoch Number 21, Index = 28/31, Loss = 2.173783302307129
# Epoch Number 21, Index = 29/31, Loss = 1.8293991088867188
# Epoch Number 21, Index = 30/31, Loss = 2.6854238510131836
# Epoch Number 21, Index = 31/31, Loss = 2.0484659671783447
# Accuracy on validation set: 30.0 %
# Epoch Number 22, Index = 0/31, Loss = 1.7308636903762817
# Epoch Number 22, Index = 1/31, Loss = 1.6450843811035156
# Epoch Number 22, Index = 2/31, Loss = 1.928801417350769
# Epoch Number 22, Index = 3/31, Loss = 2.154980182647705
# Epoch Number 22, Index = 4/31, Loss = 2.3471851348876953
# Epoch Number 22, Index = 5/31, Loss = 1.8324556350708008
# Epoch Number 22, Index = 6/31, Loss = 1.8549617528915405
# Epoch Number 22, Index = 7/31, Loss = 1.9794697761535645
# Epoch Number 22, Index = 8/31, Loss = 1.5111088752746582
# Epoch Number 22, Index = 9/31, Loss = 2.0529775619506836
# Epoch Number 22, Index = 10/31, Loss = 2.1880927085876465
# Epoch Number 22, Index = 11/31, Loss = 1.9464696645736694
# Epoch Number 22, Index = 12/31, Loss = 2.1257338523864746
# Epoch Number 22, Index = 13/31, Loss = 2.4830799102783203
# Epoch Number 22, Index = 14/31, Loss = 2.165287733078003
# Epoch Number 22, Index = 15/31, Loss = 2.107038974761963
# Epoch Number 22, Index = 16/31, Loss = 2.752302646636963
# Epoch Number 22, Index = 17/31, Loss = 2.205296039581299
# Epoch Number 22, Index = 18/31, Loss = 1.9785642623901367
# Epoch Number 22, Index = 19/31, Loss = 2.3556947708129883
# Epoch Number 22, Index = 20/31, Loss = 2.163944959640503
# Epoch Number 22, Index = 21/31, Loss = 2.4455554485321045
# Epoch Number 22, Index = 22/31, Loss = 2.3449902534484863
# Epoch Number 22, Index = 23/31, Loss = 2.091738700866699
# Epoch Number 22, Index = 24/31, Loss = 2.246121883392334
# Epoch Number 22, Index = 25/31, Loss = 2.0676584243774414
# Epoch Number 22, Index = 26/31, Loss = 2.371046781539917
# Epoch Number 22, Index = 27/31, Loss = 2.0367918014526367
# Epoch Number 22, Index = 28/31, Loss = 2.4338154792785645
# Epoch Number 22, Index = 29/31, Loss = 2.4146411418914795
# Epoch Number 22, Index = 30/31, Loss = 1.705348253250122
# Epoch Number 22, Index = 31/31, Loss = 2.097031354904175
# Accuracy on validation set: 29.019607843137255 %
# Epoch Number 23, Index = 0/31, Loss = 2.042847156524658
# Epoch Number 23, Index = 1/31, Loss = 2.058698892593384
# Epoch Number 23, Index = 2/31, Loss = 2.0975427627563477
# Epoch Number 23, Index = 3/31, Loss = 1.5392100811004639
# Epoch Number 23, Index = 4/31, Loss = 1.8527811765670776
# Epoch Number 23, Index = 5/31, Loss = 1.6362392902374268
# Epoch Number 23, Index = 6/31, Loss = 2.2719368934631348
# Epoch Number 23, Index = 7/31, Loss = 1.903707504272461
# Epoch Number 23, Index = 8/31, Loss = 2.252129316329956
# Epoch Number 23, Index = 9/31, Loss = 1.7566572427749634
# Epoch Number 23, Index = 10/31, Loss = 2.1774280071258545
# Epoch Number 23, Index = 11/31, Loss = 2.0803403854370117
# Epoch Number 23, Index = 12/31, Loss = 2.227510929107666
# Epoch Number 23, Index = 13/31, Loss = 1.7965970039367676
# Epoch Number 23, Index = 14/31, Loss = 1.8984205722808838
# Epoch Number 23, Index = 15/31, Loss = 1.7260937690734863
# Epoch Number 23, Index = 16/31, Loss = 2.1954922676086426
# Epoch Number 23, Index = 17/31, Loss = 1.6190922260284424
# Epoch Number 23, Index = 18/31, Loss = 2.0693795680999756
# Epoch Number 23, Index = 19/31, Loss = 2.242967367172241
# Epoch Number 23, Index = 20/31, Loss = 1.7228187322616577
# Epoch Number 23, Index = 21/31, Loss = 1.7234432697296143
# Epoch Number 23, Index = 22/31, Loss = 2.241347312927246
# Epoch Number 23, Index = 23/31, Loss = 1.942880630493164
# Epoch Number 23, Index = 24/31, Loss = 2.201655626296997
# Epoch Number 23, Index = 25/31, Loss = 2.120490789413452
# Epoch Number 23, Index = 26/31, Loss = 1.8392999172210693
# Epoch Number 23, Index = 27/31, Loss = 2.032805919647217
# Epoch Number 23, Index = 28/31, Loss = 2.340644598007202
# Epoch Number 23, Index = 29/31, Loss = 1.846776008605957
# Epoch Number 23, Index = 30/31, Loss = 2.40350604057312
# Epoch Number 23, Index = 31/31, Loss = 2.1371095180511475
# Accuracy on validation set: 30.19607843137255 %
# Epoch Number 24, Index = 0/31, Loss = 1.636942744255066
# Epoch Number 24, Index = 1/31, Loss = 1.6008409261703491
# Epoch Number 24, Index = 2/31, Loss = 1.9359880685806274
# Epoch Number 24, Index = 3/31, Loss = 1.3785111904144287
# Epoch Number 24, Index = 4/31, Loss = 1.9493626356124878
# Epoch Number 24, Index = 5/31, Loss = 2.253571033477783
# Epoch Number 24, Index = 6/31, Loss = 1.8205004930496216
# Epoch Number 24, Index = 7/31, Loss = 2.0363011360168457
# Epoch Number 24, Index = 8/31, Loss = 2.3971340656280518
# Epoch Number 24, Index = 9/31, Loss = 1.5546859502792358
# Epoch Number 24, Index = 10/31, Loss = 2.2265431880950928
# Epoch Number 24, Index = 11/31, Loss = 2.144789695739746
# Epoch Number 24, Index = 12/31, Loss = 2.7138538360595703
# Epoch Number 24, Index = 13/31, Loss = 1.8271307945251465
# Epoch Number 24, Index = 14/31, Loss = 2.0517683029174805
# Epoch Number 24, Index = 15/31, Loss = 1.7956199645996094
# Epoch Number 24, Index = 16/31, Loss = 2.56876277923584
# Epoch Number 24, Index = 17/31, Loss = 2.044031858444214
# Epoch Number 24, Index = 18/31, Loss = 1.774106740951538
# Epoch Number 24, Index = 19/31, Loss = 1.6308070421218872
# Epoch Number 24, Index = 20/31, Loss = 1.9093278646469116
# Epoch Number 24, Index = 21/31, Loss = 2.0830307006835938
# Epoch Number 24, Index = 22/31, Loss = 2.3743014335632324
# Epoch Number 24, Index = 23/31, Loss = 2.8311944007873535
# Epoch Number 24, Index = 24/31, Loss = 1.793200135231018
# Epoch Number 24, Index = 25/31, Loss = 2.0888524055480957
# Epoch Number 24, Index = 26/31, Loss = 2.0150599479675293
# Epoch Number 24, Index = 27/31, Loss = 1.2954046726226807
# Epoch Number 24, Index = 28/31, Loss = 2.1986026763916016
# Epoch Number 24, Index = 29/31, Loss = 2.152418851852417
# Epoch Number 24, Index = 30/31, Loss = 1.997843861579895
# Epoch Number 24, Index = 31/31, Loss = 1.7542550563812256
# Accuracy on validation set: 30.392156862745097 %
# Epoch Number 25, Index = 0/31, Loss = 1.6275813579559326
# Epoch Number 25, Index = 1/31, Loss = 2.075249195098877
# Epoch Number 25, Index = 2/31, Loss = 1.7202122211456299
# Epoch Number 25, Index = 3/31, Loss = 1.7439703941345215
# Epoch Number 25, Index = 4/31, Loss = 2.0728859901428223
# Epoch Number 25, Index = 5/31, Loss = 2.138859748840332
# Epoch Number 25, Index = 6/31, Loss = 1.6795767545700073
# Epoch Number 25, Index = 7/31, Loss = 1.5601661205291748
# Epoch Number 25, Index = 8/31, Loss = 2.0290536880493164
# Epoch Number 25, Index = 9/31, Loss = 1.7023106813430786
# Epoch Number 25, Index = 10/31, Loss = 2.487053871154785
# Epoch Number 25, Index = 11/31, Loss = 2.05073881149292
# Epoch Number 25, Index = 12/31, Loss = 1.8659751415252686
# Epoch Number 25, Index = 13/31, Loss = 1.985072135925293
# Epoch Number 25, Index = 14/31, Loss = 1.5862849950790405
# Epoch Number 25, Index = 15/31, Loss = 1.8367406129837036
# Epoch Number 25, Index = 16/31, Loss = 1.891779899597168
# Epoch Number 25, Index = 17/31, Loss = 2.2064969539642334
# Epoch Number 25, Index = 18/31, Loss = 2.1445252895355225
# Epoch Number 25, Index = 19/31, Loss = 1.8603917360305786
# Epoch Number 25, Index = 20/31, Loss = 1.815128207206726
# Epoch Number 25, Index = 21/31, Loss = 1.8573369979858398
# Epoch Number 25, Index = 22/31, Loss = 2.0062828063964844
# Epoch Number 25, Index = 23/31, Loss = 1.8240457773208618
# ...
# Epoch Number 365, Index = 9/31, Loss = 0.026553303003311157
# Epoch Number 365, Index = 10/31, Loss = 0.05391374230384827
# Epoch Number 365, Index = 11/31, Loss = 0.020065180957317352
# Epoch Number 365, Index = 12/31, Loss = 0.02471301518380642
# Epoch Number 365, Index = 13/31, Loss = 0.021212991327047348
# Epoch Number 365, Index = 14/31, Loss = 0.006950061302632093
# Epoch Number 365, Index = 15/31, Loss = 0.03785770758986473
# Epoch Number 365, Index = 16/31, Loss = 0.07379651069641113
# Epoch Number 365, Index = 17/31, Loss = 0.024971947073936462
# Epoch Number 365, Index = 18/31, Loss = 0.026337917894124985
# Epoch Number 365, Index = 19/31, Loss = 0.06642308086156845
# Epoch Number 365, Index = 20/31, Loss = 0.011518867686390877
# Epoch Number 365, Index = 21/31, Loss = 0.08120310306549072
# Epoch Number 365, Index = 22/31, Loss = 0.010164406150579453
# Epoch Number 365, Index = 23/31, Loss = 0.030605396255850792
# Epoch Number 365, Index = 24/31, Loss = 0.050452690571546555
# Epoch Number 365, Index = 25/31, Loss = 0.011499891988933086
# Epoch Number 365, Index = 26/31, Loss = 0.015195852145552635
# Epoch Number 365, Index = 27/31, Loss = 0.014079898595809937
# Epoch Number 365, Index = 28/31, Loss = 0.01410200446844101
# Epoch Number 365, Index = 29/31, Loss = 0.04177075996994972
# Epoch Number 365, Index = 30/31, Loss = 0.036967627704143524
# Epoch Number 365, Index = 31/31, Loss = 0.029828166589140892
# Accuracy on validation set: 38.627450980392155 %
# Epoch Number 366, Index = 0/31, Loss = 0.04629401117563248
# Epoch Number 366, Index = 1/31, Loss = 0.0031659407541155815
# Epoch Number 366, Index = 2/31, Loss = 0.012392081320285797
# Epoch Number 366, Index = 3/31, Loss = 0.01113181933760643
# Epoch Number 366, Index = 4/31, Loss = 0.013502757996320724
# Epoch Number 366, Index = 5/31, Loss = 0.00859781913459301
# Epoch Number 366, Index = 6/31, Loss = 0.01623491384088993
# Epoch Number 366, Index = 7/31, Loss = 0.004425123333930969
# Epoch Number 366, Index = 8/31, Loss = 0.046572260558605194
# Epoch Number 366, Index = 9/31, Loss = 0.010080147534608841
# Epoch Number 366, Index = 10/31, Loss = 0.10036664456129074
# Epoch Number 366, Index = 11/31, Loss = 0.06833549588918686
# Epoch Number 366, Index = 12/31, Loss = 0.027177002280950546
# Epoch Number 366, Index = 13/31, Loss = 0.029409438371658325
# Epoch Number 366, Index = 14/31, Loss = 0.024797599762678146
# Epoch Number 366, Index = 15/31, Loss = 0.008200380951166153
# Epoch Number 366, Index = 16/31, Loss = 0.05570428818464279
# Epoch Number 366, Index = 17/31, Loss = 0.05167298763990402
# Epoch Number 366, Index = 18/31, Loss = 0.01336233876645565
# Epoch Number 366, Index = 19/31, Loss = 0.012630226090550423
# Epoch Number 366, Index = 20/31, Loss = 0.041505392640829086
# Epoch Number 366, Index = 21/31, Loss = 0.11147940158843994
# Epoch Number 366, Index = 22/31, Loss = 0.038129713386297226
# Epoch Number 366, Index = 23/31, Loss = 0.011856980621814728
# Epoch Number 366, Index = 24/31, Loss = 0.05052609369158745
# Epoch Number 366, Index = 25/31, Loss = 0.02582339569926262
# Epoch Number 366, Index = 26/31, Loss = 0.06041392683982849
# Epoch Number 366, Index = 27/31, Loss = 0.023790843784809113
# Epoch Number 366, Index = 28/31, Loss = 0.021073512732982635
# Epoch Number 366, Index = 29/31, Loss = 0.02916187420487404
# Epoch Number 366, Index = 30/31, Loss = 0.013882750645279884
# Epoch Number 366, Index = 31/31, Loss = 0.010481208562850952
# Accuracy on validation set: 39.6078431372549 %
# Epoch Number 367, Index = 0/31, Loss = 0.07430867850780487
# Epoch Number 367, Index = 1/31, Loss = 0.05412361025810242
# Epoch Number 367, Index = 2/31, Loss = 0.041021768003702164
# Epoch Number 367, Index = 3/31, Loss = 0.005458534695208073
# Epoch Number 367, Index = 4/31, Loss = 0.014402082189917564
# Epoch Number 367, Index = 5/31, Loss = 0.025447245687246323
# Epoch Number 367, Index = 6/31, Loss = 0.06978543847799301
# Epoch Number 367, Index = 7/31, Loss = 0.08732427656650543
# Epoch Number 367, Index = 8/31, Loss = 0.00939668994396925
# Epoch Number 367, Index = 9/31, Loss = 0.06875545531511307
# Epoch Number 367, Index = 10/31, Loss = 0.026841238141059875
# Epoch Number 367, Index = 11/31, Loss = 0.009921488352119923
# Epoch Number 367, Index = 12/31, Loss = 0.05304678529500961
# Epoch Number 367, Index = 13/31, Loss = 0.07809212803840637
# Epoch Number 367, Index = 14/31, Loss = 0.00578754348680377
# Epoch Number 367, Index = 15/31, Loss = 0.007598952390253544
# Epoch Number 367, Index = 16/31, Loss = 0.014209941029548645
# Epoch Number 367, Index = 17/31, Loss = 0.009549982845783234
# Epoch Number 367, Index = 18/31, Loss = 0.012855698354542255
# Epoch Number 367, Index = 19/31, Loss = 0.01593342423439026
# Epoch Number 367, Index = 20/31, Loss = 0.055144790560007095
# Epoch Number 367, Index = 21/31, Loss = 0.055836815387010574
# Epoch Number 367, Index = 22/31, Loss = 0.030659254640340805
# Epoch Number 367, Index = 23/31, Loss = 0.016808977350592613
# Epoch Number 367, Index = 24/31, Loss = 0.07747375965118408
# Epoch Number 367, Index = 25/31, Loss = 0.026888251304626465
# Epoch Number 367, Index = 26/31, Loss = 0.03458637371659279
# Epoch Number 367, Index = 27/31, Loss = 0.03593577444553375
# Epoch Number 367, Index = 28/31, Loss = 0.02692636102437973
# Epoch Number 367, Index = 29/31, Loss = 0.025661882013082504
# Epoch Number 367, Index = 30/31, Loss = 0.01994999870657921
# Epoch Number 367, Index = 31/31, Loss = 0.18550178408622742
# Accuracy on validation set: 39.80392156862745 %
# Epoch Number 368, Index = 0/31, Loss = 0.30554312467575073
# Epoch Number 368, Index = 1/31, Loss = 0.0051632532849907875
# Epoch Number 368, Index = 2/31, Loss = 0.02741270884871483
# Epoch Number 368, Index = 3/31, Loss = 0.057968463748693466
# Epoch Number 368, Index = 4/31, Loss = 0.016671890392899513
# Epoch Number 368, Index = 5/31, Loss = 0.04744662344455719
# Epoch Number 368, Index = 6/31, Loss = 0.04038611799478531
# Epoch Number 368, Index = 7/31, Loss = 0.017145022749900818
# Epoch Number 368, Index = 8/31, Loss = 0.09120035916566849
# Epoch Number 368, Index = 9/31, Loss = 0.1053054928779602
# Epoch Number 368, Index = 10/31, Loss = 0.05379814654588699
# Epoch Number 368, Index = 11/31, Loss = 0.01689254119992256
# Epoch Number 368, Index = 12/31, Loss = 0.06669183075428009
# Epoch Number 368, Index = 13/31, Loss = 0.040347401052713394
# Epoch Number 368, Index = 14/31, Loss = 0.01559496484696865
# Epoch Number 368, Index = 15/31, Loss = 0.19273154437541962
# Epoch Number 368, Index = 16/31, Loss = 0.01932602748274803
# Epoch Number 368, Index = 17/31, Loss = 0.012960310094058514
# Epoch Number 368, Index = 18/31, Loss = 0.0075566647574305534
# Epoch Number 368, Index = 19/31, Loss = 0.01872284524142742
# Epoch Number 368, Index = 20/31, Loss = 0.01771356724202633
# Epoch Number 368, Index = 21/31, Loss = 0.015493141487240791
# Epoch Number 368, Index = 22/31, Loss = 0.014619365334510803
# Epoch Number 368, Index = 23/31, Loss = 0.031941838562488556
# Epoch Number 368, Index = 24/31, Loss = 0.0738995373249054
# Epoch Number 368, Index = 25/31, Loss = 0.19917292892932892
# Epoch Number 368, Index = 26/31, Loss = 0.014218362979590893
# Epoch Number 368, Index = 27/31, Loss = 0.08517414331436157
# Epoch Number 368, Index = 28/31, Loss = 0.15898314118385315
# Epoch Number 368, Index = 29/31, Loss = 0.13712114095687866
# Epoch Number 368, Index = 30/31, Loss = 0.03742412477731705
# Epoch Number 368, Index = 31/31, Loss = 0.01221237238496542
# Accuracy on validation set: 38.529411764705884 %
# Epoch Number 369, Index = 0/31, Loss = 0.04662705957889557
# Epoch Number 369, Index = 1/31, Loss = 0.00793024618178606
# Epoch Number 369, Index = 2/31, Loss = 0.009818018414080143
# Epoch Number 369, Index = 3/31, Loss = 0.021493716165423393
# Epoch Number 369, Index = 4/31, Loss = 0.046098630875349045
# Epoch Number 369, Index = 5/31, Loss = 0.01033991202712059
# Epoch Number 369, Index = 6/31, Loss = 0.00833374634385109
# Epoch Number 369, Index = 7/31, Loss = 0.10944484174251556
# Epoch Number 369, Index = 8/31, Loss = 0.047354601323604584
# Epoch Number 369, Index = 9/31, Loss = 0.04273349419236183
# Epoch Number 369, Index = 10/31, Loss = 0.6217484474182129
# Epoch Number 369, Index = 11/31, Loss = 0.0648960992693901
# Epoch Number 369, Index = 12/31, Loss = 0.14093175530433655
# Epoch Number 369, Index = 13/31, Loss = 0.11333586275577545
# Epoch Number 369, Index = 14/31, Loss = 0.015352101996541023
# Epoch Number 369, Index = 15/31, Loss = 0.05723179131746292
# Epoch Number 369, Index = 16/31, Loss = 0.020168259739875793
# Epoch Number 369, Index = 17/31, Loss = 0.05271098017692566
# Epoch Number 369, Index = 18/31, Loss = 0.055153414607048035
# Epoch Number 369, Index = 19/31, Loss = 0.06792008876800537
# Epoch Number 369, Index = 20/31, Loss = 0.02781546674668789
# Epoch Number 369, Index = 21/31, Loss = 0.02741173468530178
# Epoch Number 369, Index = 22/31, Loss = 0.018876144662499428
# Epoch Number 369, Index = 23/31, Loss = 0.01639440655708313
# Epoch Number 369, Index = 24/31, Loss = 0.1676173210144043
# Epoch Number 369, Index = 25/31, Loss = 0.019445065408945084
# Epoch Number 369, Index = 26/31, Loss = 0.15531502664089203
# Epoch Number 369, Index = 27/31, Loss = 0.030998852103948593
# Epoch Number 369, Index = 28/31, Loss = 0.21142956614494324
# Epoch Number 369, Index = 29/31, Loss = 0.019259627908468246
# Epoch Number 369, Index = 30/31, Loss = 0.026981372386217117
# Epoch Number 369, Index = 31/31, Loss = 0.035184528678655624
# Accuracy on validation set: 39.80392156862745 %
# Epoch Number 370, Index = 0/31, Loss = 0.07995085418224335
# Epoch Number 370, Index = 1/31, Loss = 0.020914226770401
# Epoch Number 370, Index = 2/31, Loss = 0.15435197949409485
# Epoch Number 370, Index = 3/31, Loss = 0.017900660634040833
# Epoch Number 370, Index = 4/31, Loss = 0.03380463644862175
# Epoch Number 370, Index = 5/31, Loss = 0.013791973702609539
# Epoch Number 370, Index = 6/31, Loss = 0.048356182873249054
# Epoch Number 370, Index = 7/31, Loss = 0.02477087453007698
# Epoch Number 370, Index = 8/31, Loss = 0.0189430620521307
# Epoch Number 370, Index = 9/31, Loss = 0.008945466950535774
# Epoch Number 370, Index = 10/31, Loss = 0.08675387501716614
# Epoch Number 370, Index = 11/31, Loss = 0.16269291937351227
# Epoch Number 370, Index = 12/31, Loss = 0.016344815492630005
# Epoch Number 370, Index = 13/31, Loss = 0.09787598252296448
# Epoch Number 370, Index = 14/31, Loss = 0.05175633355975151
# Epoch Number 370, Index = 15/31, Loss = 0.05593737214803696
# Epoch Number 370, Index = 16/31, Loss = 0.06930150091648102
# Epoch Number 370, Index = 17/31, Loss = 0.07336180657148361
# Epoch Number 370, Index = 18/31, Loss = 0.014725109562277794
# Epoch Number 370, Index = 19/31, Loss = 0.032079312950372696
# Epoch Number 370, Index = 20/31, Loss = 0.1181190088391304
# Epoch Number 370, Index = 21/31, Loss = 0.055881060659885406
# Epoch Number 370, Index = 22/31, Loss = 0.032668184489011765
# Epoch Number 370, Index = 23/31, Loss = 0.019708365201950073
# Epoch Number 370, Index = 24/31, Loss = 0.051407959312200546
# Epoch Number 370, Index = 25/31, Loss = 0.008193508721888065
# Epoch Number 370, Index = 26/31, Loss = 0.032375216484069824
# Epoch Number 370, Index = 27/31, Loss = 0.09399708360433578
# Epoch Number 370, Index = 28/31, Loss = 0.12340746819972992
# Epoch Number 370, Index = 29/31, Loss = 0.041306786239147186
# Epoch Number 370, Index = 30/31, Loss = 0.023271065205335617
# Epoch Number 370, Index = 31/31, Loss = 0.018529372289776802
# Accuracy on validation set: 38.92156862745098 %
# Epoch Number 371, Index = 0/31, Loss = 0.05168026313185692
# Epoch Number 371, Index = 1/31, Loss = 0.04357997700572014
# Epoch Number 371, Index = 2/31, Loss = 0.0038254023529589176
# Epoch Number 371, Index = 3/31, Loss = 0.027243658900260925
# Epoch Number 371, Index = 4/31, Loss = 0.01218518428504467
# Epoch Number 371, Index = 5/31, Loss = 0.04187662526965141
# Epoch Number 371, Index = 6/31, Loss = 0.014887887984514236
# Epoch Number 371, Index = 7/31, Loss = 0.07663486152887344
# Epoch Number 371, Index = 8/31, Loss = 0.005897358059883118
# Epoch Number 371, Index = 9/31, Loss = 0.03460046648979187
# Epoch Number 371, Index = 10/31, Loss = 0.0777578353881836
# Epoch Number 371, Index = 11/31, Loss = 0.028834937140345573
# Epoch Number 371, Index = 12/31, Loss = 0.004060939885675907
# Epoch Number 371, Index = 13/31, Loss = 0.010223474353551865
# Epoch Number 371, Index = 14/31, Loss = 0.05453537777066231
# Epoch Number 371, Index = 15/31, Loss = 0.0457293838262558
# Epoch Number 371, Index = 16/31, Loss = 0.16997025907039642
# Epoch Number 371, Index = 17/31, Loss = 0.015152527019381523
# Epoch Number 371, Index = 18/31, Loss = 0.0253741517663002
# Epoch Number 371, Index = 19/31, Loss = 0.03192012384533882
# Epoch Number 371, Index = 20/31, Loss = 0.04358735680580139
# Epoch Number 371, Index = 21/31, Loss = 0.022386623546481133
# Epoch Number 371, Index = 22/31, Loss = 0.01804208941757679
# Epoch Number 371, Index = 23/31, Loss = 0.031086666509509087
# Epoch Number 371, Index = 24/31, Loss = 0.016150841489434242
# Epoch Number 371, Index = 25/31, Loss = 0.012818451039493084
# Epoch Number 371, Index = 26/31, Loss = 0.10090411454439163
# Epoch Number 371, Index = 27/31, Loss = 0.05637696385383606
# Epoch Number 371, Index = 28/31, Loss = 0.03320647031068802
# Epoch Number 371, Index = 29/31, Loss = 0.2226099669933319
# Epoch Number 371, Index = 30/31, Loss = 0.02379070222377777
# Epoch Number 371, Index = 31/31, Loss = 0.008268507197499275
# Accuracy on validation set: 37.745098039215684 %
# Epoch Number 372, Index = 0/31, Loss = 0.08523774147033691
# Epoch Number 372, Index = 1/31, Loss = 0.008351976983249187
# Epoch Number 372, Index = 2/31, Loss = 0.020246092230081558
# Epoch Number 372, Index = 3/31, Loss = 0.03320755437016487
# Epoch Number 372, Index = 4/31, Loss = 0.014614585787057877
# Epoch Number 372, Index = 5/31, Loss = 0.007307312451303005
# Epoch Number 372, Index = 6/31, Loss = 0.013872942887246609
# Epoch Number 372, Index = 7/31, Loss = 0.05313495174050331
# Epoch Number 372, Index = 8/31, Loss = 0.03950759768486023
# Epoch Number 372, Index = 9/31, Loss = 0.011327598243951797
# Epoch Number 372, Index = 10/31, Loss = 0.014922654256224632
# Epoch Number 372, Index = 11/31, Loss = 0.019828561693429947
# Epoch Number 372, Index = 12/31, Loss = 0.051688987761735916
# Epoch Number 372, Index = 13/31, Loss = 0.031032856553792953
# Epoch Number 372, Index = 14/31, Loss = 0.082781121134758
# Epoch Number 372, Index = 15/31, Loss = 0.20018398761749268
# Epoch Number 372, Index = 16/31, Loss = 0.008555728942155838
# Epoch Number 372, Index = 17/31, Loss = 0.020893944427371025
# Epoch Number 372, Index = 18/31, Loss = 0.03781580179929733
# Epoch Number 372, Index = 19/31, Loss = 0.010874222032725811
# Epoch Number 372, Index = 20/31, Loss = 0.0662013590335846
# Epoch Number 372, Index = 21/31, Loss = 0.02684425562620163
# Epoch Number 372, Index = 22/31, Loss = 0.018164388835430145
# Epoch Number 372, Index = 23/31, Loss = 0.10480055212974548
# Epoch Number 372, Index = 24/31, Loss = 0.12003055214881897
# Epoch Number 372, Index = 25/31, Loss = 0.06736625730991364
# Epoch Number 372, Index = 26/31, Loss = 0.021633701398968697
# Epoch Number 372, Index = 27/31, Loss = 0.0036812061443924904
# Epoch Number 372, Index = 28/31, Loss = 0.2018861025571823
# Epoch Number 372, Index = 29/31, Loss = 0.011044798418879509
# Epoch Number 372, Index = 30/31, Loss = 0.027742549777030945
# Epoch Number 372, Index = 31/31, Loss = 0.08109214156866074
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 23
#      19     optimizer.step()
#      21     print(f"Epoch Number {epoch}, Index = {i}/{len(train_loader)-1}, Loss = {loss.item()}")
# ---> 23 current_accuracy = NetworkAccuracyOnValidation()
#      24 if (current_accuracy > best_accuracy):
#      25     best_accuracy = current_accuracy
#
# Cell In[5], line 21, in NetworkAccuracyOnValidation()
#      19         if label == pred:
#      20             num_class_correct[label] += 1
# ---> 21         num_class_samples[label] += 1
#      23 acc = 100.0 * total_correct / total_samples
#      24 print(f'Accuracy on validation set: {acc} %')
#
# KeyboardInterrupt:
