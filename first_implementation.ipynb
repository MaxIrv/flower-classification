# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math

# %%
transform_normal = transforms.Compose([
  transforms.Resize((250, 250)),
  transforms.ToTensor()
])

transform_train = transforms.Compose([
  transforms.Resize((250, 250)),
  transforms.ColorJitter(brightness=0.5), # Randomly change the brightness of the image  
  transforms.RandomHorizontalFlip(p=0.5), # Randomly flip the image horizontally
  transforms.RandomVerticalFlip(p=0.5), # Randomly flip the image vertically
  transforms.RandomRotation(55), # Randomly rotate the image by 45 degrees
  transforms.ToTensor(),
  # transforms.Normalize(mean = [0.0, 0.0, 0.0], std = [1.0, 1.0, 1.0]) # Takes each value for the channel, subtracts the mean and divides by the standard deviation (value - mean) / std
])

# Define the transformations
transformations1 = transforms.Compose([transforms.ToTensor(), transforms.Resize((250, 250))])

# Load the dataset
training_dataset = torchvision.datasets.Flowers102(root='./data', split="train", 
                                                   download=True, transform=transformations1)
testing_dataset = torchvision.datasets.Flowers102(root='./data', split="test",
                                                   download=True, transform=transformations1)
validation_dataset = torchvision.datasets.Flowers102(root='./data', split="val",
                                                   download=True, transform=transformations1)

# Create the dataloaders
train_loader = DataLoader(training_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(testing_dataset, batch_size=32, shuffle=False)
validation_loader = DataLoader(validation_dataset, batch_size=32, shuffle=False)

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()

    # Convolutional layers
    self.conv1 = nn.Conv2d(3, 16, 3)
    self.conv2 = nn.Conv2d(16, 32, 3)
    self.conv3 = nn.Conv2d(32, 64, 3)

    # Pooling layer
    self.pool = nn.MaxPool2d(2, 2)

    # Fully connected layers
    self.fc1 = nn.Linear(64 * 29 * 29, 512)  # Adjusted to match the output size
    self.fc2 = nn.Linear(512, 256)  # Additional fully connected layer
    self.fc3 = nn.Linear(256, 102)  # Output layer for 102 classes

    # Activation function
    self.relu_func = nn.ReLU()

  def forward(self, x):
    x = self.pool(self.relu_func(self.conv1(x)))
    x = self.pool(self.relu_func(self.conv2(x)))
    x = self.pool(self.relu_func(self.conv3(x)))
    x = x.view(-1, 64 * 29 * 29)  # Flatten the tensor
    x = self.relu_func(self.fc1(x))
    x = self.relu_func(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
device = torch.device("mps")
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
def NetworkAccuracyOnValidation():
  with torch.no_grad():
    num_class_correct = [0 for i in range(102)]
    num_class_samples = [0 for i in range(102)]
    total_correct = 0
    total_samples = 0
    for images, labels in validation_loader:
      images = images.to(device)
      labels = labels.to(device)
      outputs = model(images)
      
      _, predictions = torch.max(outputs, 1)
      total_samples += labels.size(0)
      total_correct += (predictions == labels).sum().item()
      
      for i in range(len(labels)):
        label = labels[i]
        pred = predictions[i]
        if label == pred:
          num_class_correct[label] += 1
        num_class_samples[label] += 1
        
    acc = 100.0 * total_correct / total_samples
    print(f'Accuracy on validation set: {acc} %')
    return acc

def NetworkAccuracyOnTesting():
  with torch.no_grad():
    num_class_correct = [0 for i in range(102)]
    num_class_samples = [0 for i in range(102)]
    total_correct = 0
    total_samples = 0
    for images, labels in test_loader:
      images = images.to(device)
      labels = labels.to(device)
      outputs = model(images)
      
      _, predictions = torch.max(outputs, 1)
      total_samples += labels.size(0)
      total_correct += (predictions == labels).sum().item()
      
      for i in range(len(labels)):
        label = labels[i]
        pred = predictions[i]
        if (label == pred):
          num_class_correct[label] += 1
        num_class_samples[label] += 1
        
    acc = 100.0 * total_correct / total_samples
    print(f'Accuracy on testing set: {acc} %')
    
    for i in range(102):
      acc = 100.0 * num_class_correct[i] / num_class_samples[i]
      print(f'Accuracy of {i} : {acc} %')
    
    return acc

# %%
best_accuracy_epoch = 0
best_accuracy = 0

for epoch in range(60):  # Loop over the dataset multiple times
    running_loss = 0.0
    for i, (images, labels) in enumerate(train_loader, 0):
        images = images.to(device)
        labels = labels.to(device)
        
        label_pred = model(images)
        loss = criterion(label_pred, labels)
        
        predicted = torch.max(label_pred, 1)[1]
        batch_corr = (predicted == labels).sum()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        print(f"Epoch Number {epoch}, Index = {i}/{len(train_loader)-1}, Loss = {loss.item()}")
    
    current_accuracy = NetworkAccuracyOnValidation()
    if (current_accuracy > best_accuracy):
        best_accuracy = current_accuracy
        best_accuracy_epoch = epoch
        
print(f"Best accuracy on validation split: {best_accuracy} at epoch {best_accuracy_epoch}")
model.eval()
NetworkAccuracyOnTesting()
# Out:
# Epoch Number 0, Index = 0/32, Loss = 4.62310791015625
# Epoch Number 0, Index = 1/32, Loss = 4.636667251586914
# Epoch Number 0, Index = 2/32, Loss = 4.646744251251221
# Epoch Number 0, Index = 3/32, Loss = 4.646437644958496
# Epoch Number 0, Index = 4/32, Loss = 4.644448280334473
# Epoch Number 0, Index = 5/32, Loss = 4.63398551940918
# Epoch Number 0, Index = 6/32, Loss = 4.61731481552124
# Epoch Number 0, Index = 7/32, Loss = 4.621794700622559
# Epoch Number 0, Index = 8/32, Loss = 4.605494022369385
# Epoch Number 0, Index = 9/32, Loss = 4.620713710784912
# Epoch Number 0, Index = 10/32, Loss = 4.645491600036621
# Epoch Number 0, Index = 11/32, Loss = 4.636074542999268
# Epoch Number 0, Index = 12/32, Loss = 4.59263277053833
# Epoch Number 0, Index = 13/32, Loss = 4.641700267791748
# Epoch Number 0, Index = 14/32, Loss = 4.625215530395508
# Epoch Number 0, Index = 15/32, Loss = 4.674539089202881
# Epoch Number 0, Index = 16/32, Loss = 4.6392292976379395
# Epoch Number 0, Index = 17/32, Loss = 4.644235610961914
# Epoch Number 0, Index = 18/32, Loss = 4.6231536865234375
# Epoch Number 0, Index = 19/32, Loss = 4.6473493576049805
# Epoch Number 0, Index = 20/32, Loss = 4.618535041809082
# Epoch Number 0, Index = 21/32, Loss = 4.654847145080566
# Epoch Number 0, Index = 22/32, Loss = 4.637648105621338
# Epoch Number 0, Index = 23/32, Loss = 4.620594024658203
# Epoch Number 0, Index = 24/32, Loss = 4.610658645629883
# Epoch Number 0, Index = 25/32, Loss = 4.645573616027832
# Epoch Number 0, Index = 26/32, Loss = 4.617988109588623
# Epoch Number 0, Index = 27/32, Loss = 4.62197732925415
# Epoch Number 0, Index = 28/32, Loss = 4.631900310516357
# Epoch Number 0, Index = 29/32, Loss = 4.641712665557861
# Epoch Number 0, Index = 30/32, Loss = 4.633666038513184
# Epoch Number 0, Index = 31/32, Loss = 4.626652240753174
# Accuracy on validation set: 0.6862745098039216 %
# Epoch Number 1, Index = 0/32, Loss = 4.622006416320801
# Epoch Number 1, Index = 1/32, Loss = 4.616296768188477
# Epoch Number 1, Index = 2/32, Loss = 4.602898120880127
# Epoch Number 1, Index = 3/32, Loss = 4.616361618041992
# Epoch Number 1, Index = 4/32, Loss = 4.619219779968262
# Epoch Number 1, Index = 5/32, Loss = 4.6043572425842285
# Epoch Number 1, Index = 6/32, Loss = 4.617757320404053
# Epoch Number 1, Index = 7/32, Loss = 4.592633247375488
# Epoch Number 1, Index = 8/32, Loss = 4.602099418640137
# Epoch Number 1, Index = 9/32, Loss = 4.600847244262695
# Epoch Number 1, Index = 10/32, Loss = 4.622676849365234
# Epoch Number 1, Index = 11/32, Loss = 4.607321262359619
# Epoch Number 1, Index = 12/32, Loss = 4.590977668762207
# Epoch Number 1, Index = 13/32, Loss = 4.6058454513549805
# Epoch Number 1, Index = 14/32, Loss = 4.61558198928833
# Epoch Number 1, Index = 15/32, Loss = 4.58490514755249
# Epoch Number 1, Index = 16/32, Loss = 4.613673686981201
# Epoch Number 1, Index = 17/32, Loss = 4.611059188842773
# Epoch Number 1, Index = 18/32, Loss = 4.596113204956055
# Epoch Number 1, Index = 19/32, Loss = 4.597053527832031
# Epoch Number 1, Index = 20/32, Loss = 4.583523750305176
# Epoch Number 1, Index = 21/32, Loss = 4.611346244812012
# Epoch Number 1, Index = 22/32, Loss = 4.584285259246826
# Epoch Number 1, Index = 23/32, Loss = 4.583001613616943
# Epoch Number 1, Index = 24/32, Loss = 4.5809125900268555
# Epoch Number 1, Index = 25/32, Loss = 4.556951999664307
# Epoch Number 1, Index = 26/32, Loss = 4.578805923461914
# Epoch Number 1, Index = 27/32, Loss = 4.564032554626465
# Epoch Number 1, Index = 28/32, Loss = 4.532320976257324
# Epoch Number 1, Index = 29/32, Loss = 4.605436325073242
# Epoch Number 1, Index = 30/32, Loss = 4.57619047164917
# Epoch Number 1, Index = 31/32, Loss = 4.508459568023682
# Accuracy on validation set: 0.9803921568627451 %
# Epoch Number 2, Index = 0/32, Loss = 4.544708251953125
# Epoch Number 2, Index = 1/32, Loss = 4.493888854980469
# Epoch Number 2, Index = 2/32, Loss = 4.5345869064331055
# Epoch Number 2, Index = 3/32, Loss = 4.467792510986328
# Epoch Number 2, Index = 4/32, Loss = 4.541924953460693
# Epoch Number 2, Index = 5/32, Loss = 4.541781902313232
# Epoch Number 2, Index = 6/32, Loss = 4.451883316040039
# Epoch Number 2, Index = 7/32, Loss = 4.483660697937012
# Epoch Number 2, Index = 8/32, Loss = 4.463715553283691
# Epoch Number 2, Index = 9/32, Loss = 4.560944557189941
# Epoch Number 2, Index = 10/32, Loss = 4.556002616882324
# Epoch Number 2, Index = 11/32, Loss = 4.472238063812256
# Epoch Number 2, Index = 12/32, Loss = 4.508759498596191
# Epoch Number 2, Index = 13/32, Loss = 4.473633766174316
# Epoch Number 2, Index = 14/32, Loss = 4.512322425842285
# Epoch Number 2, Index = 15/32, Loss = 4.475226402282715
# Epoch Number 2, Index = 16/32, Loss = 4.460086822509766
# Epoch Number 2, Index = 17/32, Loss = 4.434471130371094
# Epoch Number 2, Index = 18/32, Loss = 4.487980365753174
# Epoch Number 2, Index = 19/32, Loss = 4.519384384155273
# Epoch Number 2, Index = 20/32, Loss = 4.502931594848633
# Epoch Number 2, Index = 21/32, Loss = 4.399440765380859
# Epoch Number 2, Index = 22/32, Loss = 4.428940773010254
# Epoch Number 2, Index = 23/32, Loss = 4.452937126159668
# Epoch Number 2, Index = 24/32, Loss = 4.421079635620117
# Epoch Number 2, Index = 25/32, Loss = 4.341161727905273
# Epoch Number 2, Index = 26/32, Loss = 4.561971664428711
# Epoch Number 2, Index = 27/32, Loss = 4.37564754486084
# Epoch Number 2, Index = 28/32, Loss = 4.322692394256592
# Epoch Number 2, Index = 29/32, Loss = 4.475893020629883
# Epoch Number 2, Index = 30/32, Loss = 4.331996917724609
# Epoch Number 2, Index = 31/32, Loss = 4.343973159790039
# Accuracy on validation set: 2.9411764705882355 %
# Epoch Number 3, Index = 0/32, Loss = 4.2929887771606445
# Epoch Number 3, Index = 1/32, Loss = 4.310325622558594
# Epoch Number 3, Index = 2/32, Loss = 4.367609977722168
# Epoch Number 3, Index = 3/32, Loss = 4.301460266113281
# Epoch Number 3, Index = 4/32, Loss = 4.277965545654297
# Epoch Number 3, Index = 5/32, Loss = 4.1864519119262695
# Epoch Number 3, Index = 6/32, Loss = 4.337189674377441
# Epoch Number 3, Index = 7/32, Loss = 4.257755279541016
# Epoch Number 3, Index = 8/32, Loss = 4.276591777801514
# Epoch Number 3, Index = 9/32, Loss = 4.1452436447143555
# Epoch Number 3, Index = 10/32, Loss = 4.218594074249268
# Epoch Number 3, Index = 11/32, Loss = 4.110733985900879
# Epoch Number 3, Index = 12/32, Loss = 4.147152900695801
# Epoch Number 3, Index = 13/32, Loss = 4.302399158477783
# Epoch Number 3, Index = 14/32, Loss = 4.276634216308594
# Epoch Number 3, Index = 15/32, Loss = 4.078141689300537
# Epoch Number 3, Index = 16/32, Loss = 4.289786338806152
# Epoch Number 3, Index = 17/32, Loss = 4.1600661277771
# Epoch Number 3, Index = 18/32, Loss = 4.204790115356445
# Epoch Number 3, Index = 19/32, Loss = 4.040684700012207
# Epoch Number 3, Index = 20/32, Loss = 4.038736820220947
# Epoch Number 3, Index = 21/32, Loss = 4.09092903137207
# Epoch Number 3, Index = 22/32, Loss = 4.135735034942627
# Epoch Number 3, Index = 23/32, Loss = 4.058907985687256
# Epoch Number 3, Index = 24/32, Loss = 4.1732025146484375
# Epoch Number 3, Index = 25/32, Loss = 3.986262321472168
# Epoch Number 3, Index = 26/32, Loss = 4.053384780883789
# Epoch Number 3, Index = 27/32, Loss = 4.058323860168457
# Epoch Number 3, Index = 28/32, Loss = 4.092360496520996
# Epoch Number 3, Index = 29/32, Loss = 4.341773986816406
# Epoch Number 3, Index = 30/32, Loss = 4.079020023345947
# Epoch Number 3, Index = 31/32, Loss = 4.018269062042236
# Accuracy on validation set: 4.607843137254902 %
# Epoch Number 4, Index = 0/32, Loss = 3.9718880653381348
# Epoch Number 4, Index = 1/32, Loss = 4.009127616882324
# Epoch Number 4, Index = 2/32, Loss = 3.9974818229675293
# Epoch Number 4, Index = 3/32, Loss = 3.8590259552001953
# Epoch Number 4, Index = 4/32, Loss = 3.9954111576080322
# Epoch Number 4, Index = 5/32, Loss = 4.024021148681641
# Epoch Number 4, Index = 6/32, Loss = 4.01289176940918
# Epoch Number 4, Index = 7/32, Loss = 3.766328811645508
# Epoch Number 4, Index = 8/32, Loss = 3.92441463470459
# Epoch Number 4, Index = 9/32, Loss = 3.8681795597076416
# Epoch Number 4, Index = 10/32, Loss = 3.774514675140381
# Epoch Number 4, Index = 11/32, Loss = 3.959223747253418
# Epoch Number 4, Index = 12/32, Loss = 4.159366130828857
# Epoch Number 4, Index = 13/32, Loss = 4.09535026550293
# Epoch Number 4, Index = 14/32, Loss = 3.923447608947754
# Epoch Number 4, Index = 15/32, Loss = 4.004909515380859
# Epoch Number 4, Index = 16/32, Loss = 3.8247737884521484
# Epoch Number 4, Index = 17/32, Loss = 3.906494379043579
# Epoch Number 4, Index = 18/32, Loss = 3.9696123600006104
# Epoch Number 4, Index = 19/32, Loss = 3.7111096382141113
# Epoch Number 4, Index = 20/32, Loss = 3.5898079872131348
# Epoch Number 4, Index = 21/32, Loss = 3.8739964962005615
# Epoch Number 4, Index = 22/32, Loss = 3.6577672958374023
# Epoch Number 4, Index = 23/32, Loss = 3.7645187377929688
# Epoch Number 4, Index = 24/32, Loss = 3.5781121253967285
# Epoch Number 4, Index = 25/32, Loss = 3.7101335525512695
# Epoch Number 4, Index = 26/32, Loss = 3.759552001953125
# Epoch Number 4, Index = 27/32, Loss = 3.6857852935791016
# Epoch Number 4, Index = 28/32, Loss = 3.6353681087493896
# Epoch Number 4, Index = 29/32, Loss = 3.7123336791992188
# Epoch Number 4, Index = 30/32, Loss = 3.8291897773742676
# Epoch Number 4, Index = 31/32, Loss = 3.9259045124053955
# Accuracy on validation set: 7.450980392156863 %
# Epoch Number 5, Index = 0/32, Loss = 3.861037492752075
# Epoch Number 5, Index = 1/32, Loss = 3.4398746490478516
# Epoch Number 5, Index = 2/32, Loss = 3.4412357807159424
# Epoch Number 5, Index = 3/32, Loss = 3.330782413482666
# Epoch Number 5, Index = 4/32, Loss = 3.6289398670196533
# Epoch Number 5, Index = 5/32, Loss = 3.594531536102295
# Epoch Number 5, Index = 6/32, Loss = 3.542172908782959
# Epoch Number 5, Index = 7/32, Loss = 3.6265721321105957
# Epoch Number 5, Index = 8/32, Loss = 3.5978028774261475
# Epoch Number 5, Index = 9/32, Loss = 3.523576259613037
# Epoch Number 5, Index = 10/32, Loss = 3.602630853652954
# Epoch Number 5, Index = 11/32, Loss = 3.654411792755127
# Epoch Number 5, Index = 12/32, Loss = 3.3285536766052246
# Epoch Number 5, Index = 13/32, Loss = 3.313298225402832
# Epoch Number 5, Index = 14/32, Loss = 3.555706024169922
# Epoch Number 5, Index = 15/32, Loss = 3.5008621215820312
# Epoch Number 5, Index = 16/32, Loss = 3.4752554893493652
# Epoch Number 5, Index = 17/32, Loss = 3.556912899017334
# Epoch Number 5, Index = 18/32, Loss = 3.6507391929626465
# Epoch Number 5, Index = 19/32, Loss = 3.6920526027679443
# Epoch Number 5, Index = 20/32, Loss = 3.347228765487671
# Epoch Number 5, Index = 21/32, Loss = 3.544463634490967
# Epoch Number 5, Index = 22/32, Loss = 3.4797449111938477
# Epoch Number 5, Index = 23/32, Loss = 3.34271240234375
# Epoch Number 5, Index = 24/32, Loss = 3.49918794631958
# Epoch Number 5, Index = 25/32, Loss = 3.3948631286621094
# Epoch Number 5, Index = 26/32, Loss = 3.382399559020996
# Epoch Number 5, Index = 27/32, Loss = 3.4753975868225098
# Epoch Number 5, Index = 28/32, Loss = 3.570474624633789
# Epoch Number 5, Index = 29/32, Loss = 3.7172210216522217
# Epoch Number 5, Index = 30/32, Loss = 2.9631502628326416
# Epoch Number 5, Index = 31/32, Loss = 3.566380023956299
# Accuracy on validation set: 8.72549019607843 %
# Epoch Number 6, Index = 0/32, Loss = 3.256281852722168
# Epoch Number 6, Index = 1/32, Loss = 3.5233373641967773
# Epoch Number 6, Index = 2/32, Loss = 3.2963695526123047
# Epoch Number 6, Index = 3/32, Loss = 3.289212942123413
# Epoch Number 6, Index = 4/32, Loss = 3.400784492492676
# Epoch Number 6, Index = 5/32, Loss = 3.145399570465088
# Epoch Number 6, Index = 6/32, Loss = 3.2290186882019043
# Epoch Number 6, Index = 7/32, Loss = 3.06794810295105
# Epoch Number 6, Index = 8/32, Loss = 3.229273796081543
# Epoch Number 6, Index = 9/32, Loss = 3.102849006652832
# Epoch Number 6, Index = 10/32, Loss = 3.5118329524993896
# Epoch Number 6, Index = 11/32, Loss = 3.2681825160980225
# Epoch Number 6, Index = 12/32, Loss = 3.156255006790161
# Epoch Number 6, Index = 13/32, Loss = 3.044373035430908
# Epoch Number 6, Index = 14/32, Loss = 2.877692699432373
# Epoch Number 6, Index = 15/32, Loss = 3.1435303688049316
# Epoch Number 6, Index = 16/32, Loss = 3.2421247959136963
# Epoch Number 6, Index = 17/32, Loss = 3.1715586185455322
# Epoch Number 6, Index = 18/32, Loss = 3.311710834503174
# Epoch Number 6, Index = 19/32, Loss = 3.133112907409668
# Epoch Number 6, Index = 20/32, Loss = 3.024362087249756
# Epoch Number 6, Index = 21/32, Loss = 3.107926845550537
# Epoch Number 6, Index = 22/32, Loss = 3.480013132095337
# Epoch Number 6, Index = 23/32, Loss = 3.6411609649658203
# Epoch Number 6, Index = 24/32, Loss = 3.4109344482421875
# Epoch Number 6, Index = 25/32, Loss = 2.810124397277832
# Epoch Number 6, Index = 26/32, Loss = 3.1518027782440186
# Epoch Number 6, Index = 27/32, Loss = 3.0712392330169678
# Epoch Number 6, Index = 28/32, Loss = 2.8826050758361816
# Epoch Number 6, Index = 29/32, Loss = 3.1073787212371826
# Epoch Number 6, Index = 30/32, Loss = 3.0830953121185303
# Epoch Number 6, Index = 31/32, Loss = 3.01507306098938
# Accuracy on validation set: 11.862745098039216 %
# Epoch Number 7, Index = 0/32, Loss = 3.1343259811401367
# Epoch Number 7, Index = 1/32, Loss = 2.9250903129577637
# Epoch Number 7, Index = 2/32, Loss = 2.8271565437316895
# Epoch Number 7, Index = 3/32, Loss = 3.0729823112487793
# Epoch Number 7, Index = 4/32, Loss = 2.881317615509033
# Epoch Number 7, Index = 5/32, Loss = 2.8231804370880127
# Epoch Number 7, Index = 6/32, Loss = 2.954261302947998
# Epoch Number 7, Index = 7/32, Loss = 2.727229595184326
# Epoch Number 7, Index = 8/32, Loss = 2.9980268478393555
# Epoch Number 7, Index = 9/32, Loss = 2.9210095405578613
# Epoch Number 7, Index = 10/32, Loss = 3.0207529067993164
# Epoch Number 7, Index = 11/32, Loss = 3.004171848297119
# Epoch Number 7, Index = 12/32, Loss = 3.19431734085083
# Epoch Number 7, Index = 13/32, Loss = 2.926480293273926
# Epoch Number 7, Index = 14/32, Loss = 2.584045886993408
# Epoch Number 7, Index = 15/32, Loss = 2.831010341644287
# Epoch Number 7, Index = 16/32, Loss = 2.6958372592926025
# Epoch Number 7, Index = 17/32, Loss = 2.737168312072754
# Epoch Number 7, Index = 18/32, Loss = 2.929327964782715
# Epoch Number 7, Index = 19/32, Loss = 2.606940746307373
# Epoch Number 7, Index = 20/32, Loss = 3.17651104927063
# Epoch Number 7, Index = 21/32, Loss = 3.403848648071289
# Epoch Number 7, Index = 22/32, Loss = 2.7936391830444336
# Epoch Number 7, Index = 23/32, Loss = 2.9090375900268555
# Epoch Number 7, Index = 24/32, Loss = 2.5829524993896484
# Epoch Number 7, Index = 25/32, Loss = 3.1690804958343506
# Epoch Number 7, Index = 26/32, Loss = 2.77554988861084
# Epoch Number 7, Index = 27/32, Loss = 2.421013832092285
# Epoch Number 7, Index = 28/32, Loss = 2.7884514331817627
# Epoch Number 7, Index = 29/32, Loss = 2.5949530601501465
# Epoch Number 7, Index = 30/32, Loss = 2.6112871170043945
# Epoch Number 7, Index = 31/32, Loss = 2.619847536087036
# Accuracy on validation set: 13.627450980392156 %
# Epoch Number 8, Index = 0/32, Loss = 2.48390531539917
# Epoch Number 8, Index = 1/32, Loss = 2.5061469078063965
# Epoch Number 8, Index = 2/32, Loss = 2.5405187606811523
# Epoch Number 8, Index = 3/32, Loss = 2.7565267086029053
# Epoch Number 8, Index = 4/32, Loss = 2.687906503677368
# Epoch Number 8, Index = 5/32, Loss = 2.9351205825805664
# Epoch Number 8, Index = 6/32, Loss = 2.481685161590576
# Epoch Number 8, Index = 7/32, Loss = 2.441783905029297
# Epoch Number 8, Index = 8/32, Loss = 2.206721782684326
# Epoch Number 8, Index = 9/32, Loss = 2.7638611793518066
# Epoch Number 8, Index = 10/32, Loss = 2.033918857574463
# Epoch Number 8, Index = 11/32, Loss = 2.316448211669922
# Epoch Number 8, Index = 12/32, Loss = 2.2886862754821777
# Epoch Number 8, Index = 13/32, Loss = 2.691607713699341
# Epoch Number 8, Index = 14/32, Loss = 2.883345127105713
# Epoch Number 8, Index = 15/32, Loss = 2.3059277534484863
# Epoch Number 8, Index = 16/32, Loss = 2.5299735069274902
# Epoch Number 8, Index = 17/32, Loss = 2.5552868843078613
# Epoch Number 8, Index = 18/32, Loss = 2.739553213119507
# Epoch Number 8, Index = 19/32, Loss = 2.26700758934021
# Epoch Number 8, Index = 20/32, Loss = 2.5098204612731934
# Epoch Number 8, Index = 21/32, Loss = 2.6213698387145996
# Epoch Number 8, Index = 22/32, Loss = 2.4586844444274902
# Epoch Number 8, Index = 23/32, Loss = 2.4929938316345215
# Epoch Number 8, Index = 24/32, Loss = 2.093675136566162
# Epoch Number 8, Index = 25/32, Loss = 2.218804359436035
# Epoch Number 8, Index = 26/32, Loss = 2.8540709018707275
# Epoch Number 8, Index = 27/32, Loss = 2.3465025424957275
# Epoch Number 8, Index = 28/32, Loss = 2.571641683578491
# Epoch Number 8, Index = 29/32, Loss = 2.6581649780273438
# Epoch Number 8, Index = 30/32, Loss = 2.9607176780700684
# Epoch Number 8, Index = 31/32, Loss = 3.0599637031555176
# Accuracy on validation set: 13.823529411764707 %
# Epoch Number 9, Index = 0/32, Loss = 2.407565116882324
# Epoch Number 9, Index = 1/32, Loss = 2.2976818084716797
# Epoch Number 9, Index = 2/32, Loss = 2.0086920261383057
# Epoch Number 9, Index = 3/32, Loss = 2.0093138217926025
# Epoch Number 9, Index = 4/32, Loss = 1.7369582653045654
# Epoch Number 9, Index = 5/32, Loss = 2.201568126678467
# Epoch Number 9, Index = 6/32, Loss = 2.0880188941955566
# Epoch Number 9, Index = 7/32, Loss = 2.333163022994995
# Epoch Number 9, Index = 8/32, Loss = 2.4884133338928223
# Epoch Number 9, Index = 9/32, Loss = 2.297459125518799
# Epoch Number 9, Index = 10/32, Loss = 2.2507922649383545
# Epoch Number 9, Index = 11/32, Loss = 2.4475250244140625
# Epoch Number 9, Index = 12/32, Loss = 1.998748540878296
# Epoch Number 9, Index = 13/32, Loss = 2.9177255630493164
# Epoch Number 9, Index = 14/32, Loss = 1.7332110404968262
# Epoch Number 9, Index = 15/32, Loss = 2.143008232116699
# Epoch Number 9, Index = 16/32, Loss = 1.927296757698059
# Epoch Number 9, Index = 17/32, Loss = 2.325490951538086
# Epoch Number 9, Index = 18/32, Loss = 2.306100845336914
# Epoch Number 9, Index = 19/32, Loss = 2.380568027496338
# Epoch Number 9, Index = 20/32, Loss = 2.1587774753570557
# Epoch Number 9, Index = 21/32, Loss = 2.040543794631958
# Epoch Number 9, Index = 22/32, Loss = 2.256376266479492
# Epoch Number 9, Index = 23/32, Loss = 2.035912036895752
# Epoch Number 9, Index = 24/32, Loss = 1.756557822227478
# Epoch Number 9, Index = 25/32, Loss = 2.117234706878662
# Epoch Number 9, Index = 26/32, Loss = 2.3460865020751953
# Epoch Number 9, Index = 27/32, Loss = 2.2102253437042236
# Epoch Number 9, Index = 28/32, Loss = 2.0747227668762207
# Epoch Number 9, Index = 29/32, Loss = 2.263216018676758
# Epoch Number 9, Index = 30/32, Loss = 2.4975385665893555
# Epoch Number 9, Index = 31/32, Loss = 2.156320333480835
# Accuracy on validation set: 14.607843137254902 %
# Epoch Number 10, Index = 0/32, Loss = 1.810049295425415
# Epoch Number 10, Index = 1/32, Loss = 1.6489646434783936
# Epoch Number 10, Index = 2/32, Loss = 1.6548351049423218
# Epoch Number 10, Index = 3/32, Loss = 2.0089006423950195
# Epoch Number 10, Index = 4/32, Loss = 2.0456881523132324
# Epoch Number 10, Index = 5/32, Loss = 2.204995632171631
# Epoch Number 10, Index = 6/32, Loss = 2.139443874359131
# Epoch Number 10, Index = 7/32, Loss = 2.2256524562835693
# Epoch Number 10, Index = 8/32, Loss = 1.9002629518508911
# Epoch Number 10, Index = 9/32, Loss = 1.9246695041656494
# Epoch Number 10, Index = 10/32, Loss = 1.438978910446167
# Epoch Number 10, Index = 11/32, Loss = 1.7062562704086304
# Epoch Number 10, Index = 12/32, Loss = 1.8465485572814941
# Epoch Number 10, Index = 13/32, Loss = 2.0711557865142822
# Epoch Number 10, Index = 14/32, Loss = 2.041189193725586
# Epoch Number 10, Index = 15/32, Loss = 1.7357652187347412
# Epoch Number 10, Index = 16/32, Loss = 1.87437105178833
# Epoch Number 10, Index = 17/32, Loss = 1.7625324726104736
# Epoch Number 10, Index = 18/32, Loss = 1.866605281829834
# Epoch Number 10, Index = 19/32, Loss = 1.8538414239883423
# Epoch Number 10, Index = 20/32, Loss = 1.8394371271133423
# Epoch Number 10, Index = 21/32, Loss = 1.851289987564087
# Epoch Number 10, Index = 22/32, Loss = 2.0095455646514893
# Epoch Number 10, Index = 23/32, Loss = 1.9744911193847656
# Epoch Number 10, Index = 24/32, Loss = 2.3049979209899902
# Epoch Number 10, Index = 25/32, Loss = 1.3697617053985596
# Epoch Number 10, Index = 26/32, Loss = 1.8841322660446167
# Epoch Number 10, Index = 27/32, Loss = 1.9554377794265747
# Epoch Number 10, Index = 28/32, Loss = 1.548364281654358
# Epoch Number 10, Index = 29/32, Loss = 1.7756304740905762
# Epoch Number 10, Index = 30/32, Loss = 2.3872575759887695
# Epoch Number 10, Index = 31/32, Loss = 1.8236522674560547
# Accuracy on validation set: 16.470588235294116 %
# Epoch Number 11, Index = 0/32, Loss = 1.6560006141662598
# Epoch Number 11, Index = 1/32, Loss = 1.901179552078247
# Epoch Number 11, Index = 2/32, Loss = 1.2118535041809082
# Epoch Number 11, Index = 3/32, Loss = 1.704633116722107
# Epoch Number 11, Index = 4/32, Loss = 1.4436708688735962
# Epoch Number 11, Index = 5/32, Loss = 1.0899477005004883
# Epoch Number 11, Index = 6/32, Loss = 1.403730034828186
# Epoch Number 11, Index = 7/32, Loss = 1.653641939163208
# Epoch Number 11, Index = 8/32, Loss = 1.5586961507797241
# Epoch Number 11, Index = 9/32, Loss = 1.6321403980255127
# Epoch Number 11, Index = 10/32, Loss = 1.5011405944824219
# Epoch Number 11, Index = 11/32, Loss = 1.6650362014770508
# Epoch Number 11, Index = 12/32, Loss = 1.5046031475067139
# Epoch Number 11, Index = 13/32, Loss = 2.0118658542633057
# Epoch Number 11, Index = 14/32, Loss = 1.3256171941757202
# Epoch Number 11, Index = 15/32, Loss = 1.6530570983886719
# Epoch Number 11, Index = 16/32, Loss = 1.3207014799118042
# Epoch Number 11, Index = 17/32, Loss = 1.6694953441619873
# Epoch Number 11, Index = 18/32, Loss = 1.664865255355835
# Epoch Number 11, Index = 19/32, Loss = 2.0867018699645996
# Epoch Number 11, Index = 20/32, Loss = 1.5463275909423828
# Epoch Number 11, Index = 21/32, Loss = 1.6073956489562988
# Epoch Number 11, Index = 22/32, Loss = 1.924149751663208
# Epoch Number 11, Index = 23/32, Loss = 1.3883638381958008
# Epoch Number 11, Index = 24/32, Loss = 1.828066349029541
# Epoch Number 11, Index = 25/32, Loss = 2.004086971282959
# Epoch Number 11, Index = 26/32, Loss = 2.0046281814575195
# Epoch Number 11, Index = 27/32, Loss = 1.6019290685653687
# Epoch Number 11, Index = 28/32, Loss = 1.4838862419128418
# Epoch Number 11, Index = 29/32, Loss = 1.6450276374816895
# Epoch Number 11, Index = 30/32, Loss = 1.5335028171539307
# Epoch Number 11, Index = 31/32, Loss = 1.7054184675216675
# Accuracy on validation set: 15.686274509803921 %
# Epoch Number 12, Index = 0/32, Loss = 1.7059227228164673
# Epoch Number 12, Index = 1/32, Loss = 1.3248121738433838
# Epoch Number 12, Index = 2/32, Loss = 1.4348337650299072
# Epoch Number 12, Index = 3/32, Loss = 1.1452462673187256
# Epoch Number 12, Index = 4/32, Loss = 1.848341464996338
# Epoch Number 12, Index = 5/32, Loss = 1.0748252868652344
# Epoch Number 12, Index = 6/32, Loss = 1.5780072212219238
# Epoch Number 12, Index = 7/32, Loss = 1.2308322191238403
# Epoch Number 12, Index = 8/32, Loss = 1.3495343923568726
# Epoch Number 12, Index = 9/32, Loss = 1.3716261386871338
# Epoch Number 12, Index = 10/32, Loss = 1.7086795568466187
# Epoch Number 12, Index = 11/32, Loss = 1.5577828884124756
# Epoch Number 12, Index = 12/32, Loss = 1.3949081897735596
# Epoch Number 12, Index = 13/32, Loss = 1.5562198162078857
# Epoch Number 12, Index = 14/32, Loss = 1.3738090991973877
# Epoch Number 12, Index = 15/32, Loss = 1.6626975536346436
# Epoch Number 12, Index = 16/32, Loss = 1.3869894742965698
# Epoch Number 12, Index = 17/32, Loss = 1.1396983861923218
# Epoch Number 12, Index = 18/32, Loss = 1.3794773817062378
# Epoch Number 12, Index = 19/32, Loss = 1.7168865203857422
# Epoch Number 12, Index = 20/32, Loss = 1.4066612720489502
# Epoch Number 12, Index = 21/32, Loss = 1.3326423168182373
# Epoch Number 12, Index = 22/32, Loss = 1.208417534828186
# Epoch Number 12, Index = 23/32, Loss = 1.7416715621948242
# Epoch Number 12, Index = 24/32, Loss = 1.5545921325683594
# Epoch Number 12, Index = 25/32, Loss = 1.6660054922103882
# Epoch Number 12, Index = 26/32, Loss = 1.064594030380249
# Epoch Number 12, Index = 27/32, Loss = 0.9887580275535583
# Epoch Number 12, Index = 28/32, Loss = 1.1322228908538818
# Epoch Number 12, Index = 29/32, Loss = 1.2101969718933105
# Epoch Number 12, Index = 30/32, Loss = 1.1608967781066895
# Epoch Number 12, Index = 31/32, Loss = 1.3888827562332153
# Accuracy on validation set: 17.54901960784314 %
# Epoch Number 13, Index = 0/32, Loss = 1.1570653915405273
# Epoch Number 13, Index = 1/32, Loss = 1.1150338649749756
# Epoch Number 13, Index = 2/32, Loss = 0.9683297276496887
# Epoch Number 13, Index = 3/32, Loss = 0.9977625608444214
# Epoch Number 13, Index = 4/32, Loss = 1.1111725568771362
# Epoch Number 13, Index = 5/32, Loss = 1.0044524669647217
# Epoch Number 13, Index = 6/32, Loss = 0.962169349193573
# Epoch Number 13, Index = 7/32, Loss = 1.1450358629226685
# Epoch Number 13, Index = 8/32, Loss = 1.249402642250061
# Epoch Number 13, Index = 9/32, Loss = 1.0555717945098877
# Epoch Number 13, Index = 10/32, Loss = 1.6586437225341797
# Epoch Number 13, Index = 11/32, Loss = 1.1450659036636353
# Epoch Number 13, Index = 12/32, Loss = 0.7719776630401611
# Epoch Number 13, Index = 13/32, Loss = 1.254792332649231
# Epoch Number 13, Index = 14/32, Loss = 1.271304726600647
# Epoch Number 13, Index = 15/32, Loss = 0.908516526222229
# Epoch Number 13, Index = 16/32, Loss = 1.2345279455184937
# Epoch Number 13, Index = 17/32, Loss = 1.1384119987487793
# Epoch Number 13, Index = 18/32, Loss = 1.3287396430969238
# Epoch Number 13, Index = 19/32, Loss = 1.0761160850524902
# Epoch Number 13, Index = 20/32, Loss = 1.2147308588027954
# Epoch Number 13, Index = 21/32, Loss = 1.2374699115753174
# Epoch Number 13, Index = 22/32, Loss = 1.1575450897216797
# Epoch Number 13, Index = 23/32, Loss = 0.9134117364883423
# Epoch Number 13, Index = 24/32, Loss = 1.294850468635559
# Epoch Number 13, Index = 25/32, Loss = 0.9945486187934875
# Epoch Number 13, Index = 26/32, Loss = 1.0674407482147217
# Epoch Number 13, Index = 27/32, Loss = 1.2617847919464111
# Epoch Number 13, Index = 28/32, Loss = 1.2021650075912476
# Epoch Number 13, Index = 29/32, Loss = 0.9056495428085327
# Epoch Number 13, Index = 30/32, Loss = 0.9989733695983887
# Epoch Number 13, Index = 31/32, Loss = 1.2719976902008057
# Accuracy on validation set: 16.372549019607842 %
# Epoch Number 14, Index = 0/32, Loss = 0.7413280606269836
# Epoch Number 14, Index = 1/32, Loss = 0.7194287180900574
# Epoch Number 14, Index = 2/32, Loss = 0.7713457942008972
# Epoch Number 14, Index = 3/32, Loss = 1.049386978149414
# Epoch Number 14, Index = 4/32, Loss = 1.1773531436920166
# Epoch Number 14, Index = 5/32, Loss = 0.5929714441299438
# Epoch Number 14, Index = 6/32, Loss = 1.060110092163086
# Epoch Number 14, Index = 7/32, Loss = 0.9502872228622437
# Epoch Number 14, Index = 8/32, Loss = 1.365105390548706
# Epoch Number 14, Index = 9/32, Loss = 1.614762544631958
# Epoch Number 14, Index = 10/32, Loss = 0.7599390745162964
# Epoch Number 14, Index = 11/32, Loss = 0.8577505350112915
# Epoch Number 14, Index = 12/32, Loss = 0.7386047840118408
# Epoch Number 14, Index = 13/32, Loss = 0.4908212125301361
# Epoch Number 14, Index = 14/32, Loss = 1.0302313566207886
# Epoch Number 14, Index = 15/32, Loss = 0.9227816462516785
# Epoch Number 14, Index = 16/32, Loss = 1.1068257093429565
# Epoch Number 14, Index = 17/32, Loss = 0.600021481513977
# Epoch Number 14, Index = 18/32, Loss = 0.9381633996963501
# Epoch Number 14, Index = 19/32, Loss = 0.7379792332649231
# Epoch Number 14, Index = 20/32, Loss = 0.568859338760376
# Epoch Number 14, Index = 21/32, Loss = 0.6413882970809937
# Epoch Number 14, Index = 22/32, Loss = 1.3299355506896973
# Epoch Number 14, Index = 23/32, Loss = 1.4898643493652344
# Epoch Number 14, Index = 24/32, Loss = 0.5403522253036499
# Epoch Number 14, Index = 25/32, Loss = 1.025123119354248
# Epoch Number 14, Index = 26/32, Loss = 0.9909306764602661
# Epoch Number 14, Index = 27/32, Loss = 0.9203555583953857
# Epoch Number 14, Index = 28/32, Loss = 1.1402082443237305
# Epoch Number 14, Index = 29/32, Loss = 0.7767012715339661
# Epoch Number 14, Index = 30/32, Loss = 0.7001403570175171
# Epoch Number 14, Index = 31/32, Loss = 0.9579090476036072
# Accuracy on validation set: 19.41176470588235 %
# Epoch Number 15, Index = 0/32, Loss = 0.6254839897155762
# Epoch Number 15, Index = 1/32, Loss = 0.8901035785675049
# Epoch Number 15, Index = 2/32, Loss = 0.8511675596237183
# Epoch Number 15, Index = 3/32, Loss = 0.7100460529327393
# Epoch Number 15, Index = 4/32, Loss = 0.7298539876937866
# Epoch Number 15, Index = 5/32, Loss = 0.95061856508255
# Epoch Number 15, Index = 6/32, Loss = 0.7879633903503418
# Epoch Number 15, Index = 7/32, Loss = 0.6843142509460449
# Epoch Number 15, Index = 8/32, Loss = 0.9347134828567505
# Epoch Number 15, Index = 9/32, Loss = 0.5052182674407959
# Epoch Number 15, Index = 10/32, Loss = 0.6741069555282593
# Epoch Number 15, Index = 11/32, Loss = 0.8748255968093872
# Epoch Number 15, Index = 12/32, Loss = 0.7595488429069519
# Epoch Number 15, Index = 13/32, Loss = 0.7907514572143555
# Epoch Number 15, Index = 14/32, Loss = 0.705940842628479
# Epoch Number 15, Index = 15/32, Loss = 0.6610471606254578
# Epoch Number 15, Index = 16/32, Loss = 0.9838476181030273
# Epoch Number 15, Index = 17/32, Loss = 0.6171755194664001
# Epoch Number 15, Index = 18/32, Loss = 0.8114224076271057
# Epoch Number 15, Index = 19/32, Loss = 0.8371435403823853
# Epoch Number 15, Index = 20/32, Loss = 0.9583017826080322
# Epoch Number 15, Index = 21/32, Loss = 0.9403149485588074
# Epoch Number 15, Index = 22/32, Loss = 0.7849860191345215
# Epoch Number 15, Index = 23/32, Loss = 0.7925392389297485
# Epoch Number 15, Index = 24/32, Loss = 0.9093554615974426
# Epoch Number 15, Index = 25/32, Loss = 0.7104631662368774
# Epoch Number 15, Index = 26/32, Loss = 0.943182110786438
# Epoch Number 15, Index = 27/32, Loss = 0.5404908657073975
# Epoch Number 15, Index = 28/32, Loss = 0.6926890015602112
# Epoch Number 15, Index = 29/32, Loss = 0.5729095339775085
# Epoch Number 15, Index = 30/32, Loss = 1.0234390497207642
# Epoch Number 15, Index = 31/32, Loss = 0.9441776871681213
# Accuracy on validation set: 17.254901960784313 %
# Epoch Number 16, Index = 0/32, Loss = 0.49332672357559204
# Epoch Number 16, Index = 1/32, Loss = 0.6790199279785156
# Epoch Number 16, Index = 2/32, Loss = 0.7021965980529785
# Epoch Number 16, Index = 3/32, Loss = 0.9146329760551453
# Epoch Number 16, Index = 4/32, Loss = 0.506690263748169
# Epoch Number 16, Index = 5/32, Loss = 0.6261498332023621
# Epoch Number 16, Index = 6/32, Loss = 0.4477885961532593
# Epoch Number 16, Index = 7/32, Loss = 0.9128677845001221
# Epoch Number 16, Index = 8/32, Loss = 0.7496737837791443
# Epoch Number 16, Index = 9/32, Loss = 0.7392327785491943
# Epoch Number 16, Index = 10/32, Loss = 0.6567410826683044
# Epoch Number 16, Index = 11/32, Loss = 0.5404215455055237
# Epoch Number 16, Index = 12/32, Loss = 0.6186951398849487
# Epoch Number 16, Index = 13/32, Loss = 1.0850698947906494
# Epoch Number 16, Index = 14/32, Loss = 0.765989363193512
# Epoch Number 16, Index = 15/32, Loss = 0.47236454486846924
# Epoch Number 16, Index = 16/32, Loss = 0.5307417511940002
# Epoch Number 16, Index = 17/32, Loss = 0.9269145727157593
# Epoch Number 16, Index = 18/32, Loss = 0.5482798218727112
# Epoch Number 16, Index = 19/32, Loss = 0.5328806638717651
# Epoch Number 16, Index = 20/32, Loss = 0.9798847436904907
# Epoch Number 16, Index = 21/32, Loss = 0.5479130148887634
# Epoch Number 16, Index = 22/32, Loss = 0.5202091932296753
# Epoch Number 16, Index = 23/32, Loss = 0.8253211975097656
# Epoch Number 16, Index = 24/32, Loss = 0.5767597556114197
# Epoch Number 16, Index = 25/32, Loss = 0.5978972911834717
# Epoch Number 16, Index = 26/32, Loss = 0.6167359352111816
# Epoch Number 16, Index = 27/32, Loss = 0.5501412153244019
# Epoch Number 16, Index = 28/32, Loss = 0.5315035581588745
# Epoch Number 16, Index = 29/32, Loss = 0.4491850733757019
# Epoch Number 16, Index = 30/32, Loss = 0.5320687294006348
# Epoch Number 16, Index = 31/32, Loss = 0.5602877736091614
# Accuracy on validation set: 17.647058823529413 %
# Epoch Number 17, Index = 0/32, Loss = 0.4375847578048706
# Epoch Number 17, Index = 1/32, Loss = 0.6910024881362915
# Epoch Number 17, Index = 2/32, Loss = 0.4324914813041687
# Epoch Number 17, Index = 3/32, Loss = 0.47172272205352783
# Epoch Number 17, Index = 4/32, Loss = 0.3167208731174469
# Epoch Number 17, Index = 5/32, Loss = 0.46462133526802063
# Epoch Number 17, Index = 6/32, Loss = 0.3472554683685303
# Epoch Number 17, Index = 7/32, Loss = 0.5045164823532104
# Epoch Number 17, Index = 8/32, Loss = 0.5825667381286621
# Epoch Number 17, Index = 9/32, Loss = 0.5544458031654358
# Epoch Number 17, Index = 10/32, Loss = 0.5092089772224426
# Epoch Number 17, Index = 11/32, Loss = 0.7225435972213745
# Epoch Number 17, Index = 12/32, Loss = 0.38699930906295776
# Epoch Number 17, Index = 13/32, Loss = 0.40623074769973755
# Epoch Number 17, Index = 14/32, Loss = 0.30513596534729004
# Epoch Number 17, Index = 15/32, Loss = 0.6778801679611206
# Epoch Number 17, Index = 16/32, Loss = 0.639498233795166
# Epoch Number 17, Index = 17/32, Loss = 0.4028157889842987
# Epoch Number 17, Index = 18/32, Loss = 0.542060136795044
# Epoch Number 17, Index = 19/32, Loss = 0.48789331316947937
# Epoch Number 17, Index = 20/32, Loss = 0.3988214433193207
# Epoch Number 17, Index = 21/32, Loss = 0.2981826663017273
# Epoch Number 17, Index = 22/32, Loss = 0.429690420627594
# Epoch Number 17, Index = 23/32, Loss = 0.3619842529296875
# Epoch Number 17, Index = 24/32, Loss = 0.46312224864959717
# Epoch Number 17, Index = 25/32, Loss = 0.5242069363594055
# Epoch Number 17, Index = 26/32, Loss = 0.4220024347305298
# Epoch Number 17, Index = 27/32, Loss = 0.4562125504016876
# Epoch Number 17, Index = 28/32, Loss = 0.738449215888977
# Epoch Number 17, Index = 29/32, Loss = 0.61350417137146
# Epoch Number 17, Index = 30/32, Loss = 0.4719102084636688
# Epoch Number 17, Index = 31/32, Loss = 0.3577863276004791
# Accuracy on validation set: 17.54901960784314 %
# Epoch Number 18, Index = 0/32, Loss = 0.492972195148468
# Epoch Number 18, Index = 1/32, Loss = 0.28948158025741577
# Epoch Number 18, Index = 2/32, Loss = 0.3761875033378601
# Epoch Number 18, Index = 3/32, Loss = 0.4376475214958191
# Epoch Number 18, Index = 4/32, Loss = 0.6366172432899475
# Epoch Number 18, Index = 5/32, Loss = 0.3816211223602295
# Epoch Number 18, Index = 6/32, Loss = 0.31466543674468994
# Epoch Number 18, Index = 7/32, Loss = 0.3083032965660095
# Epoch Number 18, Index = 8/32, Loss = 0.5700139999389648
# Epoch Number 18, Index = 9/32, Loss = 0.408593088388443
# Epoch Number 18, Index = 10/32, Loss = 0.5039117932319641
# Epoch Number 18, Index = 11/32, Loss = 0.4252658486366272
# Epoch Number 18, Index = 12/32, Loss = 0.3140067458152771
# Epoch Number 18, Index = 13/32, Loss = 0.2673242688179016
# Epoch Number 18, Index = 14/32, Loss = 0.21759381890296936
# Epoch Number 18, Index = 15/32, Loss = 0.29756489396095276
# Epoch Number 18, Index = 16/32, Loss = 0.35387858748435974
# Epoch Number 18, Index = 17/32, Loss = 0.5074238777160645
# Epoch Number 18, Index = 18/32, Loss = 0.3646557331085205
# Epoch Number 18, Index = 19/32, Loss = 0.24848073720932007
# Epoch Number 18, Index = 20/32, Loss = 0.3501785099506378
# Epoch Number 18, Index = 21/32, Loss = 0.3683403730392456
# Epoch Number 18, Index = 22/32, Loss = 0.29204636812210083
# Epoch Number 18, Index = 23/32, Loss = 0.28880587220191956
# Epoch Number 18, Index = 24/32, Loss = 0.36141347885131836
# Epoch Number 18, Index = 25/32, Loss = 0.34931284189224243
# Epoch Number 18, Index = 26/32, Loss = 0.3886745572090149
# Epoch Number 18, Index = 27/32, Loss = 0.44150590896606445
# Epoch Number 18, Index = 28/32, Loss = 0.45242488384246826
# Epoch Number 18, Index = 29/32, Loss = 0.36115679144859314
# Epoch Number 18, Index = 30/32, Loss = 0.343552827835083
# Epoch Number 18, Index = 31/32, Loss = 0.22498568892478943
# Accuracy on validation set: 18.333333333333332 %
# Epoch Number 19, Index = 0/32, Loss = 0.28268879652023315
# Epoch Number 19, Index = 1/32, Loss = 0.19529098272323608
# Epoch Number 19, Index = 2/32, Loss = 0.21796546876430511
# Epoch Number 19, Index = 3/32, Loss = 0.18950141966342926
# Epoch Number 19, Index = 4/32, Loss = 0.2174144834280014
# Epoch Number 19, Index = 5/32, Loss = 0.36127570271492004
# Epoch Number 19, Index = 6/32, Loss = 0.36017167568206787
# Epoch Number 19, Index = 7/32, Loss = 0.25096940994262695
# Epoch Number 19, Index = 8/32, Loss = 0.33661866188049316
# Epoch Number 19, Index = 9/32, Loss = 0.29268088936805725
# Epoch Number 19, Index = 10/32, Loss = 0.19266679883003235
# Epoch Number 19, Index = 11/32, Loss = 0.3436502516269684
# Epoch Number 19, Index = 12/32, Loss = 0.13118134438991547
# Epoch Number 19, Index = 13/32, Loss = 0.12031229585409164
# Epoch Number 19, Index = 14/32, Loss = 0.4504964351654053
# Epoch Number 19, Index = 15/32, Loss = 0.23905913531780243
# Epoch Number 19, Index = 16/32, Loss = 0.31485235691070557
# Epoch Number 19, Index = 17/32, Loss = 0.24122029542922974
# Epoch Number 19, Index = 18/32, Loss = 0.32448866963386536
# Epoch Number 19, Index = 19/32, Loss = 0.2013779729604721
# Epoch Number 19, Index = 20/32, Loss = 0.34187591075897217
# Epoch Number 19, Index = 21/32, Loss = 0.26928314566612244
# Epoch Number 19, Index = 22/32, Loss = 0.2256658673286438
# Epoch Number 19, Index = 23/32, Loss = 0.6193999648094177
# Epoch Number 19, Index = 24/32, Loss = 0.16947810351848602
# Epoch Number 19, Index = 25/32, Loss = 0.2515680491924286
# Epoch Number 19, Index = 26/32, Loss = 0.29298245906829834
# Epoch Number 19, Index = 27/32, Loss = 0.2985870838165283
# Epoch Number 19, Index = 28/32, Loss = 0.4373432993888855
# Epoch Number 19, Index = 29/32, Loss = 0.2236272096633911
# Epoch Number 19, Index = 30/32, Loss = 0.4656296968460083
# Epoch Number 19, Index = 31/32, Loss = 0.24106428027153015
# Accuracy on validation set: 17.352941176470587 %
# Epoch Number 20, Index = 0/32, Loss = 0.16276873648166656
# Epoch Number 20, Index = 1/32, Loss = 0.25465840101242065
# Epoch Number 20, Index = 2/32, Loss = 0.3498091697692871
# Epoch Number 20, Index = 3/32, Loss = 0.22688248753547668
# Epoch Number 20, Index = 4/32, Loss = 0.35385191440582275
# Epoch Number 20, Index = 5/32, Loss = 0.13075584173202515
# Epoch Number 20, Index = 6/32, Loss = 0.16284146904945374
# Epoch Number 20, Index = 7/32, Loss = 0.12515416741371155
# Epoch Number 20, Index = 8/32, Loss = 0.1500696986913681
# Epoch Number 20, Index = 9/32, Loss = 0.24686726927757263
# Epoch Number 20, Index = 10/32, Loss = 0.14648203551769257
# Epoch Number 20, Index = 11/32, Loss = 0.3060500919818878
# Epoch Number 20, Index = 12/32, Loss = 0.1352580487728119
# Epoch Number 20, Index = 13/32, Loss = 0.23373833298683167
# Epoch Number 20, Index = 14/32, Loss = 0.3391200006008148
# Epoch Number 20, Index = 15/32, Loss = 0.3393864929676056
# Epoch Number 20, Index = 16/32, Loss = 0.2233746200799942
# Epoch Number 20, Index = 17/32, Loss = 0.19358178973197937
# Epoch Number 20, Index = 18/32, Loss = 0.22814476490020752
# Epoch Number 20, Index = 19/32, Loss = 0.23913244903087616
# Epoch Number 20, Index = 20/32, Loss = 0.15187156200408936
# Epoch Number 20, Index = 21/32, Loss = 0.2614312767982483
# Epoch Number 20, Index = 22/32, Loss = 0.11720544099807739
# Epoch Number 20, Index = 23/32, Loss = 0.3288412094116211
# Epoch Number 20, Index = 24/32, Loss = 0.32772254943847656
# Epoch Number 20, Index = 25/32, Loss = 0.2133021503686905
# Epoch Number 20, Index = 26/32, Loss = 0.15973153710365295
# Epoch Number 20, Index = 27/32, Loss = 0.2939920425415039
# Epoch Number 20, Index = 28/32, Loss = 0.22078248858451843
# Epoch Number 20, Index = 29/32, Loss = 0.24603807926177979
# Epoch Number 20, Index = 30/32, Loss = 0.29340285062789917
# Epoch Number 20, Index = 31/32, Loss = 0.19322320818901062
# Accuracy on validation set: 18.137254901960784 %
# Epoch Number 21, Index = 0/32, Loss = 0.16538384556770325
# Epoch Number 21, Index = 1/32, Loss = 0.12743014097213745
# Epoch Number 21, Index = 2/32, Loss = 0.17029711604118347
# Epoch Number 21, Index = 3/32, Loss = 0.08903712034225464
# Epoch Number 21, Index = 4/32, Loss = 0.3046134114265442
# Epoch Number 21, Index = 5/32, Loss = 0.11628056317567825
# Epoch Number 21, Index = 6/32, Loss = 0.16636571288108826
# Epoch Number 21, Index = 7/32, Loss = 0.12723836302757263
# Epoch Number 21, Index = 8/32, Loss = 0.1445922553539276
# Epoch Number 21, Index = 9/32, Loss = 0.20614194869995117
# Epoch Number 21, Index = 10/32, Loss = 0.05693528801202774
# Epoch Number 21, Index = 11/32, Loss = 0.07351696491241455
# Epoch Number 21, Index = 12/32, Loss = 0.186757892370224
# Epoch Number 21, Index = 13/32, Loss = 0.1016441285610199
# Epoch Number 21, Index = 14/32, Loss = 0.21519041061401367
# Epoch Number 21, Index = 15/32, Loss = 0.1804116666316986
# Epoch Number 21, Index = 16/32, Loss = 0.08621817082166672
# Epoch Number 21, Index = 17/32, Loss = 0.2881482243537903
# Epoch Number 21, Index = 18/32, Loss = 0.173648402094841
# Epoch Number 21, Index = 19/32, Loss = 0.17854274809360504
# Epoch Number 21, Index = 20/32, Loss = 0.12890738248825073
# Epoch Number 21, Index = 21/32, Loss = 0.21363596618175507
# Epoch Number 21, Index = 22/32, Loss = 0.21626922488212585
# Epoch Number 21, Index = 23/32, Loss = 0.12180595844984055
# Epoch Number 21, Index = 24/32, Loss = 0.19480600953102112
# Epoch Number 21, Index = 25/32, Loss = 0.17973949015140533
# Epoch Number 21, Index = 26/32, Loss = 0.16500231623649597
# Epoch Number 21, Index = 27/32, Loss = 0.13265299797058105
# Epoch Number 21, Index = 28/32, Loss = 0.16383500397205353
# Epoch Number 21, Index = 29/32, Loss = 0.12308237701654434
# Epoch Number 21, Index = 30/32, Loss = 0.15176843106746674
# Epoch Number 21, Index = 31/32, Loss = 0.15705767273902893
# Accuracy on validation set: 17.352941176470587 %
# Epoch Number 22, Index = 0/32, Loss = 0.08274966478347778
# Epoch Number 22, Index = 1/32, Loss = 0.07385367900133133
# Epoch Number 22, Index = 2/32, Loss = 0.11694157123565674
# Epoch Number 22, Index = 3/32, Loss = 0.07072873413562775
# Epoch Number 22, Index = 4/32, Loss = 0.10536562651395798
# Epoch Number 22, Index = 5/32, Loss = 0.04530813544988632
# Epoch Number 22, Index = 6/32, Loss = 0.1312692016363144
# Epoch Number 22, Index = 7/32, Loss = 0.12008225917816162
# Epoch Number 22, Index = 8/32, Loss = 0.08668550848960876
# Epoch Number 22, Index = 9/32, Loss = 0.13043414056301117
# Epoch Number 22, Index = 10/32, Loss = 0.08225756883621216
# Epoch Number 22, Index = 11/32, Loss = 0.09276408702135086
# Epoch Number 22, Index = 12/32, Loss = 0.1583450436592102
# Epoch Number 22, Index = 13/32, Loss = 0.0845060721039772
# Epoch Number 22, Index = 14/32, Loss = 0.058742254972457886
# Epoch Number 22, Index = 15/32, Loss = 0.07720977067947388
# Epoch Number 22, Index = 16/32, Loss = 0.12560328841209412
# Epoch Number 22, Index = 17/32, Loss = 0.13646599650382996
# Epoch Number 22, Index = 18/32, Loss = 0.12943460047245026
# Epoch Number 22, Index = 19/32, Loss = 0.11127738654613495
# Epoch Number 22, Index = 20/32, Loss = 0.133541539311409
# Epoch Number 22, Index = 21/32, Loss = 0.09383705258369446
# Epoch Number 22, Index = 22/32, Loss = 0.08159439265727997
# Epoch Number 22, Index = 23/32, Loss = 0.0767425000667572
# Epoch Number 22, Index = 24/32, Loss = 0.05776698887348175
# Epoch Number 22, Index = 25/32, Loss = 0.12368974089622498
# Epoch Number 22, Index = 26/32, Loss = 0.05222729593515396
# Epoch Number 22, Index = 27/32, Loss = 0.07643938064575195
# Epoch Number 22, Index = 28/32, Loss = 0.20740874111652374
# Epoch Number 22, Index = 29/32, Loss = 0.1065569669008255
# Epoch Number 22, Index = 30/32, Loss = 0.0792587623000145
# Epoch Number 22, Index = 31/32, Loss = 0.12093106657266617
# Accuracy on validation set: 18.627450980392158 %
# Epoch Number 23, Index = 0/32, Loss = 0.06828133016824722
# Epoch Number 23, Index = 1/32, Loss = 0.039168789982795715
# Epoch Number 23, Index = 2/32, Loss = 0.10299693048000336
# Epoch Number 23, Index = 3/32, Loss = 0.09363387525081635
# Epoch Number 23, Index = 4/32, Loss = 0.1044708713889122
# Epoch Number 23, Index = 5/32, Loss = 0.07181413471698761
# Epoch Number 23, Index = 6/32, Loss = 0.08983108401298523
# Epoch Number 23, Index = 7/32, Loss = 0.06281954050064087
# Epoch Number 23, Index = 8/32, Loss = 0.05469699949026108
# Epoch Number 23, Index = 9/32, Loss = 0.059260785579681396
# Epoch Number 23, Index = 10/32, Loss = 0.06284837424755096
# Epoch Number 23, Index = 11/32, Loss = 0.08289842307567596
# Epoch Number 23, Index = 12/32, Loss = 0.039454858750104904
# Epoch Number 23, Index = 13/32, Loss = 0.08625507354736328
# Epoch Number 23, Index = 14/32, Loss = 0.0448935367166996
# Epoch Number 23, Index = 15/32, Loss = 0.04953981935977936
# Epoch Number 23, Index = 16/32, Loss = 0.0764659196138382
# Epoch Number 23, Index = 17/32, Loss = 0.04282945394515991
# Epoch Number 23, Index = 18/32, Loss = 0.0662146657705307
# Epoch Number 23, Index = 19/32, Loss = 0.08983735740184784
# Epoch Number 23, Index = 20/32, Loss = 0.07200078666210175
# Epoch Number 23, Index = 21/32, Loss = 0.05037238821387291
# Epoch Number 23, Index = 22/32, Loss = 0.059134289622306824
# Epoch Number 23, Index = 23/32, Loss = 0.08100727200508118
# Epoch Number 23, Index = 24/32, Loss = 0.04507818818092346
# Epoch Number 23, Index = 25/32, Loss = 0.0684053897857666
# Epoch Number 23, Index = 26/32, Loss = 0.04376985505223274
# Epoch Number 23, Index = 27/32, Loss = 0.041213225573301315
# Epoch Number 23, Index = 28/32, Loss = 0.13049012422561646
# Epoch Number 23, Index = 29/32, Loss = 0.10663332045078278
# Epoch Number 23, Index = 30/32, Loss = 0.042023614048957825
# Epoch Number 23, Index = 31/32, Loss = 0.09920088201761246
# Accuracy on validation set: 16.96078431372549 %
# Epoch Number 24, Index = 0/32, Loss = 0.054688334465026855
# Epoch Number 24, Index = 1/32, Loss = 0.059723347425460815
# Epoch Number 24, Index = 2/32, Loss = 0.04896875470876694
# Epoch Number 24, Index = 3/32, Loss = 0.10465748608112335
# Epoch Number 24, Index = 4/32, Loss = 0.05324865132570267
# Epoch Number 24, Index = 5/32, Loss = 0.04595160856842995
# Epoch Number 24, Index = 6/32, Loss = 0.04621385037899017
# Epoch Number 24, Index = 7/32, Loss = 0.060148462653160095
# Epoch Number 24, Index = 8/32, Loss = 0.0323638916015625
# Epoch Number 24, Index = 9/32, Loss = 0.0440187081694603
# Epoch Number 24, Index = 10/32, Loss = 0.045730527490377426
# Epoch Number 24, Index = 11/32, Loss = 0.05058310553431511
# Epoch Number 24, Index = 12/32, Loss = 0.03855477273464203
# Epoch Number 24, Index = 13/32, Loss = 0.0504433810710907
# Epoch Number 24, Index = 14/32, Loss = 0.053141504526138306
# Epoch Number 24, Index = 15/32, Loss = 0.05424613878130913
# Epoch Number 24, Index = 16/32, Loss = 0.07466866821050644
# Epoch Number 24, Index = 17/32, Loss = 0.04174855351448059
# Epoch Number 24, Index = 18/32, Loss = 0.057220954447984695
# Epoch Number 24, Index = 19/32, Loss = 0.0764060765504837
# Epoch Number 24, Index = 20/32, Loss = 0.04066844657063484
# Epoch Number 24, Index = 21/32, Loss = 0.032514527440071106
# Epoch Number 24, Index = 22/32, Loss = 0.047247663140296936
# Epoch Number 24, Index = 23/32, Loss = 0.03149562329053879
# Epoch Number 24, Index = 24/32, Loss = 0.05313248559832573
# Epoch Number 24, Index = 25/32, Loss = 0.02612118050456047
# Epoch Number 24, Index = 26/32, Loss = 0.17890533804893494
# Epoch Number 24, Index = 27/32, Loss = 0.032589852809906006
# Epoch Number 24, Index = 28/32, Loss = 0.03333311155438423
# Epoch Number 24, Index = 29/32, Loss = 0.052010390907526016
# Epoch Number 24, Index = 30/32, Loss = 0.07113508880138397
# Epoch Number 24, Index = 31/32, Loss = 0.08309657871723175
# Accuracy on validation set: 18.823529411764707 %
# Epoch Number 25, Index = 0/32, Loss = 0.03875742852687836
# Epoch Number 25, Index = 1/32, Loss = 0.03314521163702011
# Epoch Number 25, Index = 2/32, Loss = 0.032620400190353394
# Epoch Number 25, Index = 3/32, Loss = 0.03062276542186737
# Epoch Number 25, Index = 4/32, Loss = 0.048614777624607086
# Epoch Number 25, Index = 5/32, Loss = 0.05066758766770363
# Epoch Number 25, Index = 6/32, Loss = 0.053812406957149506
# Epoch Number 25, Index = 7/32, Loss = 0.07407453656196594
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 18
#      16     optimizer.zero_grad()
#      17     loss.backward()
# ---> 18     optimizer.step()
#      20     print(f"Epoch Number {epoch}, Index = {i}/{len(train_loader)}, Loss = {loss.item()}")
#      22 current_accuracy = NetworkAccuracyOnValidation()
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/optim/adam.py:168, in Adam.step(self, closure)
#     157     beta1, beta2 = group['betas']
#     159     has_complex = self._init_group(
#     160         group,
#     161         params_with_grad,
#    (...)
#     165         max_exp_avg_sqs,
#     166         state_steps)
# --> 168     adam(
#     169         params_with_grad,
#     170         grads,
#     171         exp_avgs,
#     172         exp_avg_sqs,
#     173         max_exp_avg_sqs,
#     174         state_steps,
#     175         amsgrad=group['amsgrad'],
#     176         has_complex=has_complex,
#     177         beta1=beta1,
#     178         beta2=beta2,
#     179         lr=group['lr'],
#     180         weight_decay=group['weight_decay'],
#     181         eps=group['eps'],
#     182         maximize=group['maximize'],
#     183         foreach=group['foreach'],
#     184         capturable=group['capturable'],
#     185         differentiable=group['differentiable'],
#     186         fused=group['fused'],
#     187         grad_scale=getattr(self, "grad_scale", None),
#     188         found_inf=getattr(self, "found_inf", None),
#     189     )
#     191 return loss
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/optim/adam.py:318, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     315 else:
#     316     func = _single_tensor_adam
# --> 318 func(params,
#     319      grads,
#     320      exp_avgs,
#     321      exp_avg_sqs,
#     322      max_exp_avg_sqs,
#     323      state_steps,
#     324      amsgrad=amsgrad,
#     325      has_complex=has_complex,
#     326      beta1=beta1,
#     327      beta2=beta2,
#     328      lr=lr,
#     329      weight_decay=weight_decay,
#     330      eps=eps,
#     331      maximize=maximize,
#     332      capturable=capturable,
#     333      differentiable=differentiable,
#     334      grad_scale=grad_scale,
#     335      found_inf=found_inf)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/optim/adam.py:394, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     392 # Decay the first and second moment running average coefficient
#     393 exp_avg.lerp_(grad, 1 - beta1)
# --> 394 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     396 if capturable or differentiable:
#     397     step = step_t
#
# KeyboardInterrupt:
