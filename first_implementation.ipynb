# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math

# %%
transform_normal = transforms.Compose([
  transforms.Resize((250, 250)),
  transforms.ToTensor()
])

transform_train = transforms.Compose([
  transforms.Resize((250, 250)),
  transforms.ColorJitter(brightness=0.5), # Randomly change the brightness of the image  
  transforms.RandomHorizontalFlip(p=0.5), # Randomly flip the image horizontally
  transforms.RandomVerticalFlip(p=0.5), # Randomly flip the image vertically
  transforms.RandomRotation(55), # Randomly rotate the image by 45 degrees
  transforms.ToTensor(),
  # transforms.Normalize(mean = [0.0, 0.0, 0.0], std = [1.0, 1.0, 1.0]) # Takes each value for the channel, subtracts the mean and divides by the standard deviation (value - mean) / std
])

# Define the transformations
transformations1 = transforms.Compose([transforms.ToTensor(), transforms.Resize((250, 250))])

# Load the dataset
training_dataset = torchvision.datasets.Flowers102(root='./data', split="train", 
                                                   download=True, transform=transformations1)
testing_dataset = torchvision.datasets.Flowers102(root='./data', split="test",
                                                   download=True, transform=transformations1)
validation_dataset = torchvision.datasets.Flowers102(root='./data', split="val",
                                                   download=True, transform=transformations1)

# Create the dataloaders
train_loader = DataLoader(training_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(testing_dataset, batch_size=32, shuffle=False)
validation_loader = DataLoader(validation_dataset, batch_size=32, shuffle=False)

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.flatten = nn.Flatten()

    # Convolutional layers
    self.conv1 = nn.Conv2d(3, 16, 3)
    self.conv2 = nn.Conv2d(16, 32, 3)
    self.conv3 = nn.Conv2d(32, 64, 3)

    # Pooling layer
    self.pool = nn.MaxPool2d(2, 2)

    # Fully connected layers
    self.fc1 = nn.Linear(64 * 29 * 29, 512)  # Adjusted to match the output size
    self.fc2 = nn.Linear(512, 256)  # Additional fully connected layer
    self.fc3 = nn.Linear(256, 102)  # Output layer for 102 classes

    # Activation function
    self.relu_func = nn.ReLU()

  def forward(self, x):
    x = self.pool(self.relu_func(self.conv1(x)))
    x = self.pool(self.relu_func(self.conv2(x)))
    x = self.pool(self.relu_func(self.conv3(x)))
    # x = x.view(-1, 64 * 29 * 29)  # Flatten the tensor
    x = self.flatten(x)
    x = self.relu_func(self.fc1(x))
    x = self.relu_func(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
device = torch.device("mps")
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
def NetworkAccuracyOnValidation():
  with torch.no_grad():
    num_class_correct = [0 for i in range(102)]
    num_class_samples = [0 for i in range(102)]
    total_correct = 0
    total_samples = 0
    for images, labels in validation_loader:
      images = images.to(device)
      labels = labels.to(device)
      outputs = model(images)
      
      _, predictions = torch.max(outputs, 1)
      total_samples += labels.size(0)
      total_correct += (predictions == labels).sum().item()
      
      for i in range(len(labels)):
        label = labels[i]
        pred = predictions[i]
        if label == pred:
          num_class_correct[label] += 1
        num_class_samples[label] += 1
        
    acc = 100.0 * total_correct / total_samples
    print(f'Accuracy on validation set: {acc} %')
    return acc

def NetworkAccuracyOnTesting():
  with torch.no_grad():
    num_class_correct = [0 for i in range(102)]
    num_class_samples = [0 for i in range(102)]
    total_correct = 0
    total_samples = 0
    for images, labels in test_loader:
      images = images.to(device)
      labels = labels.to(device)
      outputs = model(images)
      
      _, predictions = torch.max(outputs, 1)
      total_samples += labels.size(0)
      total_correct += (predictions == labels).sum().item()
      
      for i in range(len(labels)):
        label = labels[i]
        pred = predictions[i]
        if (label == pred):
          num_class_correct[label] += 1
        num_class_samples[label] += 1
        
    acc = 100.0 * total_correct / total_samples
    print(f'Accuracy on testing set: {acc} %')
    
    for i in range(102):
      acc = 100.0 * num_class_correct[i] / num_class_samples[i]
      print(f'Accuracy of {i} : {acc} %')
    
    return acc

# %%
best_accuracy_epoch = 0
best_accuracy = 0

for epoch in range(60):  # Loop over the dataset multiple times
    running_loss = 0.0
    for i, (images, labels) in enumerate(train_loader, 0):
        images = images.to(device)
        labels = labels.to(device)
        
        label_pred = model(images)
        loss = criterion(label_pred, labels)
        
        predicted = torch.max(label_pred, 1)[1]
        batch_corr = (predicted == labels).sum()
        batch_acc = batch_corr.item() / len(images)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        print(f"Epoch Number {epoch}, Index = {i}/{len(train_loader)-1}, Loss = {loss.item()}")
    
    current_accuracy = NetworkAccuracyOnValidation()
    if (current_accuracy > best_accuracy):
        best_accuracy = current_accuracy
        best_accuracy_epoch = epoch
        
print(f"Best accuracy on validation split: {best_accuracy} at epoch {best_accuracy_epoch}")
model.eval()
NetworkAccuracyOnTesting()
# Out:
# Epoch Number 0, Index = 0/31, Loss = 0.0018324546981602907, Accuracy = 1.0
# Epoch Number 0, Index = 1/31, Loss = 0.001557139097712934, Accuracy = 1.0
# Epoch Number 0, Index = 2/31, Loss = 0.0019872160628437996, Accuracy = 1.0
# Epoch Number 0, Index = 3/31, Loss = 0.0016919372137635946, Accuracy = 1.0
# Epoch Number 0, Index = 4/31, Loss = 0.0018877165857702494, Accuracy = 1.0
# Epoch Number 0, Index = 5/31, Loss = 0.0018433561781421304, Accuracy = 1.0
# Epoch Number 0, Index = 6/31, Loss = 0.0018977122381329536, Accuracy = 1.0
# Epoch Number 0, Index = 7/31, Loss = 0.0016233716160058975, Accuracy = 1.0
# Epoch Number 0, Index = 8/31, Loss = 0.001712003257125616, Accuracy = 1.0
# Epoch Number 0, Index = 9/31, Loss = 0.0021550538949668407, Accuracy = 1.0
# Epoch Number 0, Index = 10/31, Loss = 0.001656235079281032, Accuracy = 1.0
# Epoch Number 0, Index = 11/31, Loss = 0.002186413388699293, Accuracy = 1.0
# Epoch Number 0, Index = 12/31, Loss = 0.0014620943693444133, Accuracy = 1.0
# Epoch Number 0, Index = 13/31, Loss = 0.002178828464820981, Accuracy = 1.0
# Epoch Number 0, Index = 14/31, Loss = 0.0013803740730509162, Accuracy = 1.0
# Epoch Number 0, Index = 15/31, Loss = 0.001693438389338553, Accuracy = 1.0
# Epoch Number 0, Index = 16/31, Loss = 0.001883809920400381, Accuracy = 1.0
# Epoch Number 0, Index = 17/31, Loss = 0.0014985144371166825, Accuracy = 1.0
# Epoch Number 0, Index = 18/31, Loss = 0.0018659532070159912, Accuracy = 1.0
# Epoch Number 0, Index = 19/31, Loss = 0.0015559779712930322, Accuracy = 1.0
# Epoch Number 0, Index = 20/31, Loss = 0.002060697413980961, Accuracy = 1.0
# Epoch Number 0, Index = 21/31, Loss = 0.002630382077768445, Accuracy = 1.0
# Epoch Number 0, Index = 22/31, Loss = 0.0022106266114860773, Accuracy = 1.0
# Epoch Number 0, Index = 23/31, Loss = 0.002104717306792736, Accuracy = 1.0
# Epoch Number 0, Index = 24/31, Loss = 0.0019274181686341763, Accuracy = 1.0
# Epoch Number 0, Index = 25/31, Loss = 0.0018693889724090695, Accuracy = 1.0
# Epoch Number 0, Index = 26/31, Loss = 0.001548107131384313, Accuracy = 1.0
# Epoch Number 0, Index = 27/31, Loss = 0.001768917078152299, Accuracy = 1.0
# Epoch Number 0, Index = 28/31, Loss = 0.0017427216516807675, Accuracy = 1.0
# Epoch Number 0, Index = 29/31, Loss = 0.0017029220471158624, Accuracy = 1.0
# Epoch Number 0, Index = 30/31, Loss = 0.0012054933467879891, Accuracy = 1.0
# Epoch Number 0, Index = 31/31, Loss = 0.0020013712346553802, Accuracy = 1.0
# Accuracy on validation set: 17.84313725490196 %
# Epoch Number 1, Index = 0/31, Loss = 0.0013362925965338945, Accuracy = 1.0
# Epoch Number 1, Index = 1/31, Loss = 0.0017485808348283172, Accuracy = 1.0
# Epoch Number 1, Index = 2/31, Loss = 0.001282949815504253, Accuracy = 1.0
# Epoch Number 1, Index = 3/31, Loss = 0.0015093544498085976, Accuracy = 1.0
# Epoch Number 1, Index = 4/31, Loss = 0.0015713623724877834, Accuracy = 1.0
# Epoch Number 1, Index = 5/31, Loss = 0.0017752619460225105, Accuracy = 1.0
# Epoch Number 1, Index = 6/31, Loss = 0.0014294424327090383, Accuracy = 1.0
# Epoch Number 1, Index = 7/31, Loss = 0.0021155979484319687, Accuracy = 1.0
# Epoch Number 1, Index = 8/31, Loss = 0.0017135512316599488, Accuracy = 1.0
# Epoch Number 1, Index = 9/31, Loss = 0.0018653316656127572, Accuracy = 1.0
# Epoch Number 1, Index = 10/31, Loss = 0.0014661012683063745, Accuracy = 1.0
# Epoch Number 1, Index = 11/31, Loss = 0.0018374886130914092, Accuracy = 1.0
# Epoch Number 1, Index = 12/31, Loss = 0.001959230052307248, Accuracy = 1.0
# Epoch Number 1, Index = 13/31, Loss = 0.001675385283306241, Accuracy = 1.0
# Epoch Number 1, Index = 14/31, Loss = 0.002092749811708927, Accuracy = 1.0
# Epoch Number 1, Index = 15/31, Loss = 0.0013324737083166838, Accuracy = 1.0
# Epoch Number 1, Index = 16/31, Loss = 0.001861601835116744, Accuracy = 1.0
# Epoch Number 1, Index = 17/31, Loss = 0.001851260312832892, Accuracy = 1.0
# Epoch Number 1, Index = 18/31, Loss = 0.0019581113010644913, Accuracy = 1.0
# Epoch Number 1, Index = 19/31, Loss = 0.0019002796616405249, Accuracy = 1.0
# Epoch Number 1, Index = 20/31, Loss = 0.0012751264730468392, Accuracy = 1.0
# Epoch Number 1, Index = 21/31, Loss = 0.0016987108392640948, Accuracy = 1.0
# Epoch Number 1, Index = 22/31, Loss = 0.0019552602898329496, Accuracy = 1.0
# Epoch Number 1, Index = 23/31, Loss = 0.002020543906837702, Accuracy = 1.0
# Epoch Number 1, Index = 24/31, Loss = 0.0022776906844228506, Accuracy = 1.0
# Epoch Number 1, Index = 25/31, Loss = 0.0016634389758110046, Accuracy = 1.0
# Epoch Number 1, Index = 26/31, Loss = 0.0017683180049061775, Accuracy = 1.0
# Epoch Number 1, Index = 27/31, Loss = 0.0016156788915395737, Accuracy = 1.0
# Epoch Number 1, Index = 28/31, Loss = 0.0018433902878314257, Accuracy = 1.0
# Epoch Number 1, Index = 29/31, Loss = 0.001836631796322763, Accuracy = 1.0
# Epoch Number 1, Index = 30/31, Loss = 0.0014686030335724354, Accuracy = 1.0
# Epoch Number 1, Index = 31/31, Loss = 0.0018666508840397, Accuracy = 1.0
# Accuracy on validation set: 17.45098039215686 %
# Epoch Number 2, Index = 0/31, Loss = 0.001890665851533413, Accuracy = 1.0
# Epoch Number 2, Index = 1/31, Loss = 0.0015726329293102026, Accuracy = 1.0
# Epoch Number 2, Index = 2/31, Loss = 0.0021416821982711554, Accuracy = 1.0
# Epoch Number 2, Index = 3/31, Loss = 0.0020540894474834204, Accuracy = 1.0
# Epoch Number 2, Index = 4/31, Loss = 0.001469222828745842, Accuracy = 1.0
# Epoch Number 2, Index = 5/31, Loss = 0.0016001961193978786, Accuracy = 1.0
# Epoch Number 2, Index = 6/31, Loss = 0.0013872148701921105, Accuracy = 1.0
# Epoch Number 2, Index = 7/31, Loss = 0.0012176159070804715, Accuracy = 1.0
# Epoch Number 2, Index = 8/31, Loss = 0.0013606911525130272, Accuracy = 1.0
# Epoch Number 2, Index = 9/31, Loss = 0.001593558001331985, Accuracy = 1.0
# Epoch Number 2, Index = 10/31, Loss = 0.0013246656162664294, Accuracy = 1.0
# Epoch Number 2, Index = 11/31, Loss = 0.0013028839603066444, Accuracy = 1.0
# Epoch Number 2, Index = 12/31, Loss = 0.0014527717139571905, Accuracy = 1.0
# Epoch Number 2, Index = 13/31, Loss = 0.0022724787704646587, Accuracy = 1.0
# Epoch Number 2, Index = 14/31, Loss = 0.001509117428213358, Accuracy = 1.0
# Epoch Number 2, Index = 15/31, Loss = 0.001596095971763134, Accuracy = 1.0
# Epoch Number 2, Index = 16/31, Loss = 0.0016396823339164257, Accuracy = 1.0
# Epoch Number 2, Index = 17/31, Loss = 0.0014764396473765373, Accuracy = 1.0
# Epoch Number 2, Index = 18/31, Loss = 0.0027325297705829144, Accuracy = 1.0
# Epoch Number 2, Index = 19/31, Loss = 0.0013235174119472504, Accuracy = 1.0
# Epoch Number 2, Index = 20/31, Loss = 0.0016978275962173939, Accuracy = 1.0
# Epoch Number 2, Index = 21/31, Loss = 0.00181202357634902, Accuracy = 1.0
# Epoch Number 2, Index = 22/31, Loss = 0.0014321118360385299, Accuracy = 1.0
# Epoch Number 2, Index = 23/31, Loss = 0.0016495881136506796, Accuracy = 1.0
# Epoch Number 2, Index = 24/31, Loss = 0.0017521805129945278, Accuracy = 1.0
# Epoch Number 2, Index = 25/31, Loss = 0.0015157372690737247, Accuracy = 1.0
# Epoch Number 2, Index = 26/31, Loss = 0.0015250276774168015, Accuracy = 1.0
# Epoch Number 2, Index = 27/31, Loss = 0.001389223849400878, Accuracy = 1.0
# Epoch Number 2, Index = 28/31, Loss = 0.0020136518869549036, Accuracy = 1.0
# Epoch Number 2, Index = 29/31, Loss = 0.0015097259311005473, Accuracy = 1.0
# Epoch Number 2, Index = 30/31, Loss = 0.001652017468586564, Accuracy = 1.0
# Epoch Number 2, Index = 31/31, Loss = 0.002208614954724908, Accuracy = 1.0
# Accuracy on validation set: 17.45098039215686 %
# Epoch Number 3, Index = 0/31, Loss = 0.001588102662935853, Accuracy = 1.0
# Epoch Number 3, Index = 1/31, Loss = 0.0016111182048916817, Accuracy = 1.0
# Epoch Number 3, Index = 2/31, Loss = 0.0017073997296392918, Accuracy = 1.0
# Epoch Number 3, Index = 3/31, Loss = 0.0018280905205756426, Accuracy = 1.0
# Epoch Number 3, Index = 4/31, Loss = 0.001597020193003118, Accuracy = 1.0
# Epoch Number 3, Index = 5/31, Loss = 0.0019461228512227535, Accuracy = 1.0
# Epoch Number 3, Index = 6/31, Loss = 0.001508248969912529, Accuracy = 1.0
# Epoch Number 3, Index = 7/31, Loss = 0.001970409182831645, Accuracy = 1.0
# Epoch Number 3, Index = 8/31, Loss = 0.001309767016209662, Accuracy = 1.0
# Epoch Number 3, Index = 9/31, Loss = 0.0014186184853315353, Accuracy = 1.0
# Epoch Number 3, Index = 10/31, Loss = 0.0011431918246671557, Accuracy = 1.0
# Epoch Number 3, Index = 11/31, Loss = 0.0017321943305432796, Accuracy = 1.0
# Epoch Number 3, Index = 12/31, Loss = 0.0018273805035278201, Accuracy = 1.0
# Epoch Number 3, Index = 13/31, Loss = 0.0016209203749895096, Accuracy = 1.0
# Epoch Number 3, Index = 14/31, Loss = 0.0021536187268793583, Accuracy = 1.0
# Epoch Number 3, Index = 15/31, Loss = 0.0013867547968402505, Accuracy = 1.0
# Epoch Number 3, Index = 16/31, Loss = 0.0017620902508497238, Accuracy = 1.0
# Epoch Number 3, Index = 17/31, Loss = 0.0016415384598076344, Accuracy = 1.0
# Epoch Number 3, Index = 18/31, Loss = 0.0014281730400398374, Accuracy = 1.0
# Epoch Number 3, Index = 19/31, Loss = 0.001830200431868434, Accuracy = 1.0
# Epoch Number 3, Index = 20/31, Loss = 0.0014055494684726, Accuracy = 1.0
# Epoch Number 3, Index = 21/31, Loss = 0.00138532230630517, Accuracy = 1.0
# Epoch Number 3, Index = 22/31, Loss = 0.0012732993345707655, Accuracy = 1.0
# Epoch Number 3, Index = 23/31, Loss = 0.0016877001617103815, Accuracy = 1.0
# Epoch Number 3, Index = 24/31, Loss = 0.0017664082115516067, Accuracy = 1.0
# Epoch Number 3, Index = 25/31, Loss = 0.001427826238796115, Accuracy = 1.0
# Epoch Number 3, Index = 26/31, Loss = 0.0013454980216920376, Accuracy = 1.0
# Epoch Number 3, Index = 27/31, Loss = 0.0016339193098247051, Accuracy = 1.0
# Epoch Number 3, Index = 28/31, Loss = 0.001337892492301762, Accuracy = 1.0
# Epoch Number 3, Index = 29/31, Loss = 0.001586747937835753, Accuracy = 1.0
# Epoch Number 3, Index = 30/31, Loss = 0.001431015320122242, Accuracy = 1.0
# Epoch Number 3, Index = 31/31, Loss = 0.0013417641166597605, Accuracy = 1.0
# Accuracy on validation set: 17.745098039215687 %
# Epoch Number 4, Index = 0/31, Loss = 0.0015664964448660612, Accuracy = 1.0
# Epoch Number 4, Index = 1/31, Loss = 0.0015856213867664337, Accuracy = 1.0
# Epoch Number 4, Index = 2/31, Loss = 0.0013059219345450401, Accuracy = 1.0
# Epoch Number 4, Index = 3/31, Loss = 0.001699359156191349, Accuracy = 1.0
# Epoch Number 4, Index = 4/31, Loss = 0.0015019472921267152, Accuracy = 1.0
# Epoch Number 4, Index = 5/31, Loss = 0.0011411986779421568, Accuracy = 1.0
# Epoch Number 4, Index = 6/31, Loss = 0.001223011058755219, Accuracy = 1.0
# Epoch Number 4, Index = 7/31, Loss = 0.0019885494839400053, Accuracy = 1.0
# Epoch Number 4, Index = 8/31, Loss = 0.001450203824788332, Accuracy = 1.0
# Epoch Number 4, Index = 9/31, Loss = 0.0017728903330862522, Accuracy = 1.0
# Epoch Number 4, Index = 10/31, Loss = 0.0015196303138509393, Accuracy = 1.0
# Epoch Number 4, Index = 11/31, Loss = 0.0017208653734996915, Accuracy = 1.0
# Epoch Number 4, Index = 12/31, Loss = 0.0015051063382998109, Accuracy = 1.0
# Epoch Number 4, Index = 13/31, Loss = 0.0016815727576613426, Accuracy = 1.0
# Epoch Number 4, Index = 14/31, Loss = 0.0016881623305380344, Accuracy = 1.0
# Epoch Number 4, Index = 15/31, Loss = 0.0014370388817042112, Accuracy = 1.0
# Epoch Number 4, Index = 16/31, Loss = 0.002057426143437624, Accuracy = 1.0
# Epoch Number 4, Index = 17/31, Loss = 0.001587186474353075, Accuracy = 1.0
# Epoch Number 4, Index = 18/31, Loss = 0.0010038975160568953, Accuracy = 1.0
# Epoch Number 4, Index = 19/31, Loss = 0.0014037947403267026, Accuracy = 1.0
# Epoch Number 4, Index = 20/31, Loss = 0.001334766624495387, Accuracy = 1.0
# Epoch Number 4, Index = 21/31, Loss = 0.0017757341265678406, Accuracy = 1.0
# Epoch Number 4, Index = 22/31, Loss = 0.0016046317759901285, Accuracy = 1.0
# Epoch Number 4, Index = 23/31, Loss = 0.0014164962340146303, Accuracy = 1.0
# Epoch Number 4, Index = 24/31, Loss = 0.001335697714239359, Accuracy = 1.0
# Epoch Number 4, Index = 25/31, Loss = 0.0015954342670738697, Accuracy = 1.0
# Epoch Number 4, Index = 26/31, Loss = 0.0015910021029412746, Accuracy = 1.0
# Epoch Number 4, Index = 27/31, Loss = 0.0016669714823365211, Accuracy = 1.0
# Epoch Number 4, Index = 28/31, Loss = 0.001407849369570613, Accuracy = 1.0
# Epoch Number 4, Index = 29/31, Loss = 0.0012787729501724243, Accuracy = 1.0
# Epoch Number 4, Index = 30/31, Loss = 0.001373113365843892, Accuracy = 1.0
# Epoch Number 4, Index = 31/31, Loss = 0.0014911992475390434, Accuracy = 1.0
# Accuracy on validation set: 17.54901960784314 %
# Epoch Number 5, Index = 0/31, Loss = 0.0016216053627431393, Accuracy = 1.0
# Epoch Number 5, Index = 1/31, Loss = 0.001115148770622909, Accuracy = 1.0
# Epoch Number 5, Index = 2/31, Loss = 0.0010385812493041158, Accuracy = 1.0
# Epoch Number 5, Index = 3/31, Loss = 0.001706734299659729, Accuracy = 1.0
# Epoch Number 5, Index = 4/31, Loss = 0.0013126792619004846, Accuracy = 1.0
# Epoch Number 5, Index = 5/31, Loss = 0.0017127373721450567, Accuracy = 1.0
# Epoch Number 5, Index = 6/31, Loss = 0.0014402256347239017, Accuracy = 1.0
# Epoch Number 5, Index = 7/31, Loss = 0.0016856705769896507, Accuracy = 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       4 for epoch in range(60):  # Loop over the dataset multiple times
#       5     running_loss = 0.0
# ----> 6     for i, (images, labels) in enumerate(train_loader, 0):
#       7         images = images.to(device)
#       8         labels = labels.to(device)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/torchvision/datasets/flowers102.py:81, in Flowers102.__getitem__(self, idx)
#      79 def __getitem__(self, idx: int) -> Tuple[Any, Any]:
#      80     image_file, label = self._image_files[idx], self._labels[idx]
# ---> 81     image = PIL.Image.open(image_file).convert("RGB")
#      83     if self.transform:
#      84         image = self.transform(image)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/PIL/Image.py:922, in Image.convert(self, mode, matrix, dither, palette, colors)
#     874 def convert(
#     875     self, mode=None, matrix=None, dither=None, palette=Palette.WEB, colors=256
#     876 ):
#     877     """
#     878     Returns a converted copy of this image. For the "P" mode, this
#     879     method translates pixels through the palette.  If mode is
#    (...)
#     919     :returns: An :py:class:`~PIL.Image.Image` object.
#     920     """
# --> 922     self.load()
#     924     has_transparency = "transparency" in self.info
#     925     if not mode and self.mode == "P":
#     926         # determine default mode
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/PIL/ImageFile.py:305, in ImageFile.load(self)
#     302 self.load_end()
#     304 if self._exclusive_fp and self._close_exclusive_fp_after_loading:
# --> 305     self.fp.close()
#     306 self.fp = None
#     308 if not self.map and not LOAD_TRUNCATED_IMAGES and err_code < 0:
#     309     # still raised if decoder fails to return anything
#
# KeyboardInterrupt:
